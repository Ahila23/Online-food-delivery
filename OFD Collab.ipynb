# %%
import pandas as pd
# Load dataset
df=pd.read_csv("/content/ONINE_FOOD_DELIVERY_ANALYSIS.csv")

# Display basic summary stats
print(df.describe())
# Out:
#        Customer_Age  Delivery_Time_Min   Distance_km   Order_Value  \
# count  49907.000000       66641.000000  66530.000000  66673.000000
# mean      38.976516         127.475923     16.449242   2081.830126
# std       12.372157          90.805839     12.256742   1553.628891
# min       18.000000          20.000000      1.000000    150.000000
# 25%       28.000000          45.000000      5.470000    673.000000
# 50%       39.000000         120.000000      9.970000   1197.000000
# 75%       50.000000         210.000000     27.430000   3494.000000
# max       60.000000         300.000000     40.000000   5000.000000
#
#        Discount_Applied  Final_Amount  Delivery_Rating  Restaurant_Rating  \
# count      83285.000000  44303.000000     83477.000000      100000.000000
# mean          93.936243   1961.101190         2.991531           4.249680
# std          108.209904   1557.354417         1.414108           0.722554
# min            0.000000   -150.000000         1.000000           3.000000
# 25%           20.000000    559.000000         2.000000           3.600000
# 50%           50.000000   1156.000000         3.000000           4.200000
# 75%          100.000000   3375.000000         4.000000           4.900000
# max          300.000000   4980.000000         5.000000           5.500000
#
#        Profit_Margin
# count  100000.000000
# mean        0.150362
# std         0.201888
# min        -0.200000
# 25%        -0.020000
# 50%         0.150000
# 75%         0.320000
# max         0.500000

# %%
df
# Out:
#         Order_ID Customer_ID  Customer_Age Customer_Gender       City  \
# 0      ORD000001    CUST6948          19.0            Male        NaN
# 1      ORD000002    CUST6515           NaN          Female    Chennai
# 2      ORD000003    CUST1765           NaN            Male      Delhi
# 3      ORD000004    CUST2744           NaN            Male     Mumbai
# 4      ORD000005    CUST4389          57.0          Female    Chennai
# ...          ...         ...           ...             ...        ...
# 99995  ORD099996    CUST3722           NaN             NaN     Mumbai
# 99996  ORD099997    CUST6158           NaN            Male     Mumbai
# 99997  ORD099998    CUST2155           NaN             NaN      Delhi
# 99998  ORD099999    CUST3015           NaN          Female      Delhi
# 99999  ORD100000    CUST7959           NaN           Other  Hyderabad
#
#           Area Restaurant_ID Restaurant_Name Cuisine_Type  Order_Date  ...  \
# 0      Central        RES936   Restaurant_29      Chinese  10/20/2024  ...
# 1        North        RES689  Restaurant_419      Chinese   8/12/2024  ...
# 2          NaN        RES723  Restaurant_244      Arabian   12/8/2024  ...
# 3      Central        RES951  Restaurant_178      Chinese   10/8/2024  ...
# 4        South        RES419  Restaurant_262      Chinese    2/4/2024  ...
# ...        ...           ...             ...          ...         ...  ...
# 99995      NaN        RES295  Restaurant_500      Arabian   6/10/2024  ...
# 99996     East        RES157  Restaurant_458      Arabian   4/22/2024  ...
# 99997     East        RES287  Restaurant_273          NaN   2/23/2024  ...
# 99998    North        RES491  Restaurant_241          NaN  12/10/2024  ...
# 99999     East        RES680  Restaurant_237      Chinese         NaN  ...
#
#       Final_Amount  Payment_Mode  Order_Status  Cancellation_Reason  \
# 0              NaN           UPI     Delivered                  NaN
# 1           4849.0           COD     Delivered                  NaN
# 2            737.0        Wallet     Delivered                  NaN
# 3              NaN           UPI     Cancelled        Late Delivery
# 4            352.0          Card     Delivered                  NaN
# ...            ...           ...           ...                  ...
# 99995        132.0          Card     Delivered                  NaN
# 99996       1078.0           NaN     Delivered                  NaN
# 99997          NaN           COD     Cancelled                  NaN
# 99998          NaN           NaN     Delivered                  NaN
# 99999          NaN        Wallet     Cancelled                  NaN
#
#        Delivery_Partner_ID  Delivery_Rating Restaurant_Rating Order_Day  \
# 0                    DP563              5.0               4.4   Weekend
# 1                    DP369              5.0               4.7   Weekday
# 2                    DP580              4.0               4.9   Weekend
# 3                    DP155              2.0               3.4   Weekday
# 4                    DP728              2.0               4.4   Weekend
# ...                    ...              ...               ...       ...
# 99995                DP835              2.0               4.0   Weekday
# 99996                DP476              4.0               3.5   Weekday
# 99997                DP577              2.0               4.0   Weekday
# 99998                DP896              NaN               4.3   Weekday
# 99999                DP908              5.0               4.2   Weekday
#
#       Peak_Hour Profit_Margin
# 0          True          0.13
# 1          True          0.48
# 2          True          0.08
# 3           NaN          0.04
# 4         False          0.12
# ...         ...           ...
# 99995      True          0.17
# 99996     False         -0.15
# 99997      True          0.47
# 99998       NaN          0.44
# 99999     False          0.20
#
# [100000 rows x 25 columns]

# %%
# Step 1: Install packages
# !pip install ydata-profiling
# !apt-get install -y wkhtmltopdf
# !pip install pdfkit
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.12.3)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.0.2)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling)
#   Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (4.5.1)
# Collecting imagehash==4.3.2 (from ydata-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: wordcloud>=1.9.4 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (1.9.6)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<0.63,>=0.60 in /usr/local/lib/python3.12/dist-packages (from ydata-profiling) (0.60.0)
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from imagehash==4.3.2->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba<0.63,>=0.60->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.3)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.12/dist-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.2.25)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.12/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-2.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 17.4 MB/s eta 0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 19.6 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 87.8 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 42.8 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.7 MB/s eta 0:00:00
# Downloading puremagic-2.0.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: minify-html, filetype, puremagic, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed dacite-1.9.2 filetype-1.2.0 imagehash-4.3.2 minify-html-0.18.1 multimethod-1.12 phik-0.12.5 puremagic-2.0.0 visions-0.8.1 ydata-profiling-4.18.1
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core avahi-daemon geoclue-2.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-plugins-base
#   iio-sensor-proxy libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libavahi-core7 libavahi-glib1 libcdparanoia0 libdaemon0
#   libdouble-conversion3 libevdev2 libgstreamer-plugins-base1.0-0 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libhyphen0 libinput-bin
#   libinput10 libjson-glib-1.0-0 libjson-glib-1.0-common libmbim-glib4
#   libmbim-proxy libmd4c0 libmm-glib0 libmtdev1 libnl-genl-3-200 libnotify4
#   libnss-mdns liborc-0.4-0 libproxy1v5 libqmi-glib5 libqmi-proxy libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5positioning5 libqt5printsupport5
#   libqt5qml5 libqt5qmlmodels5 libqt5quick5 libqt5sensors5 libqt5svg5
#   libqt5webchannel5 libqt5webkit5 libqt5widgets5 librsvg2-common libsoup2.4-1
#   libsoup2.4-common libvisual-0.4-0 libwacom-bin libwacom-common libwacom9
#   libwoff1 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 modemmanager qt5-gtk-platformtheme
#   qttranslations5-l10n session-migration systemd-hwe-hwdb udev usb-modeswitch
#   usb-modeswitch-data wpasupplicant
# Suggested packages:
#   avahi-autoipd gvfs libvisual-0.4-plugins gnome-shell | notification-daemon
#   avahi-autoipd | zeroconf qt5-image-formats-plugins qtwayland5
#   qt5-qmltooling-plugins comgt wvdial wpagui libengine-pkcs11-openssl
# The following NEW packages will be installed:
#   at-spi2-core avahi-daemon geoclue-2.0 glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-plugins-base
#   iio-sensor-proxy libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data libatspi2.0-0
#   libavahi-core7 libavahi-glib1 libcdparanoia0 libdaemon0
#   libdouble-conversion3 libevdev2 libgstreamer-plugins-base1.0-0 libgtk-3-0
#   libgtk-3-bin libgtk-3-common libgudev-1.0-0 libhyphen0 libinput-bin
#   libinput10 libjson-glib-1.0-0 libjson-glib-1.0-common libmbim-glib4
#   libmbim-proxy libmd4c0 libmm-glib0 libmtdev1 libnl-genl-3-200 libnotify4
#   libnss-mdns liborc-0.4-0 libproxy1v5 libqmi-glib5 libqmi-proxy libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5positioning5 libqt5printsupport5
#   libqt5qml5 libqt5qmlmodels5 libqt5quick5 libqt5sensors5 libqt5svg5
#   libqt5webchannel5 libqt5webkit5 libqt5widgets5 librsvg2-common libsoup2.4-1
#   libsoup2.4-common libvisual-0.4-0 libwacom-bin libwacom-common libwacom9
#   libwoff1 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0
#   libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxcomposite1
#   libxkbcommon-x11-0 libxtst6 modemmanager qt5-gtk-platformtheme
#   qttranslations5-l10n session-migration systemd-hwe-hwdb udev usb-modeswitch
#   usb-modeswitch-data wkhtmltopdf wpasupplicant
# 0 upgraded, 84 newly installed, 0 to remove and 2 not upgraded.
# Need to get 41.1 MB of archives.
# After this operation, 160 MB of additional disk space will be used.
# Err:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-core7 amd64 0.8-5ubuntu5.3
#   404  Not Found [IP: 185.125.190.82 80]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdaemon0 amd64 0.14-7.1ubuntu3 [14.1 kB]
# Err:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 avahi-daemon amd64 0.8-5ubuntu5.3
#   404  Not Found [IP: 185.125.190.82 80]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdouble-conversion3 amd64 3.1.7-4 [39.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.5 [848 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5positioning5 amd64 5.15.3+dfsg-3 [223 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5printsupport5 amd64 5.15.3+dfsg-2ubuntu0.2 [214 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5qml5 amd64 5.15.3+dfsg-1 [1,472 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5qmlmodels5 amd64 5.15.3+dfsg-1 [205 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5quick5 amd64 5.15.3+dfsg-1 [1,748 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5sensors5 amd64 5.15.3-1 [123 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webchannel5 amd64 5.15.3-1 [62.9 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5webkit5 amd64 5.212.0~alpha4-15ubuntu1 [12.8 MB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.17 [1,557 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/main amd64 at-spi2-core amd64 2.44.0-3 [54.4 kB]
# Err:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-glib1 amd64 0.8-5ubuntu5.3
#   404  Not Found [IP: 185.125.190.82 80]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4,432 B]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmm-glib0 amd64 1.20.0-1~ubuntu22.04.4 [262 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3,718 B]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9,982 B]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-common all 2.74.2-3ubuntu0.6 [4,778 B]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-1 amd64 2.74.2-3ubuntu0.6 [288 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 geoclue-2.0 amd64 2.5.7-3ubuntu3 [111 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.5 [712 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 iio-sensor-proxy amd64 3.3-0ubuntu6 [34.4 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3,053 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-bin amd64 3.24.33-1ubuntu2.2 [69.6 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmbim-glib4 amd64 1.28.0-1~ubuntu20.04.2 [192 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmbim-proxy amd64 1.28.0-1~ubuntu20.04.2 [6,160 B]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnl-genl-3-200 amd64 3.5.0-0.1 [12.4 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnss-mdns amd64 0.15.1-1ubuntu1 [27.0 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libqmi-glib5 amd64 1.32.0-1ubuntu0.22.04.1 [772 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libqmi-proxy amd64 1.32.0-1ubuntu0.22.04.1 [6,072 B]
# Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 modemmanager amd64 1.20.0-1~ubuntu22.04.4 [1,094 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.6 [3,668 B]
# Get:81 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 wpasupplicant amd64 2:2.10-6ubuntu2.3 [1,482 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb-modeswitch-data all 20191128-4 [33.2 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 usb-modeswitch amd64 2.6.1-3ubuntu2 [46.0 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 wkhtmltopdf amd64 0.12.6-2 [173 kB]
# Fetched 40.9 MB in 1s (80.9 MB/s)
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/a/avahi/libavahi-core7_0.8-5ubuntu5.3_amd64.deb  404  Not Found [IP: 185.125.190.82 80]
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/a/avahi/avahi-daemon_0.8-5ubuntu5.3_amd64.deb  404  Not Found [IP: 185.125.190.82 80]
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/a/avahi/libavahi-glib1_0.8-5ubuntu5.3_amd64.deb  404  Not Found [IP: 185.125.190.82 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Collecting pdfkit
#   Downloading pdfkit-1.0.0-py3-none-any.whl.metadata (9.3 kB)
# Downloading pdfkit-1.0.0-py3-none-any.whl (12 kB)
# Installing collected packages: pdfkit
# Successfully installed pdfkit-1.0.0

# %%
# Step 2: Create HTML report

from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Data Report')
profile.to_file('report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]
#   4%|▍         | 1/25 [00:01<00:24,  1.00s/it]
#  16%|█▌        | 4/25 [00:01<00:05,  3.69it/s]
#  24%|██▍       | 6/25 [00:01<00:04,  4.53it/s]
#  32%|███▏      | 8/25 [00:01<00:03,  4.83it/s]
#  36%|███▌      | 9/25 [00:02<00:02,  5.36it/s]
#  40%|████      | 10/25 [00:02<00:03,  4.37it/s]
#  48%|████▊     | 12/25 [00:02<00:02,  5.92it/s]
#  56%|█████▌    | 14/25 [00:02<00:01,  6.65it/s]
#  60%|██████    | 15/25 [00:03<00:01,  6.39it/s]
#  68%|██████▊   | 17/25 [00:03<00:01,  5.97it/s]
#  76%|███████▌  | 19/25 [00:03<00:00,  7.01it/s]
#  84%|████████▍ | 21/25 [00:03<00:00,  7.48it/s]
# 100%|██████████| 25/25 [00:04<00:00,  6.17it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !apt clean
# !rm -rf /var/lib/apt/lists/*
# !apt update
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:7 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.3 kB]
# Get:13 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 Packages [266 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/restricted amd64 Packages [164 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages [17.5 MB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [1,792 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,877 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,652 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,120 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [37.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.9 kB]
# Get:25 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,810 kB]
# Get:26 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,780 kB]
# Get:27 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Get:28 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:29 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,921 kB]
# Fetched 57.9 MB in 3s (19.9 MB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 110 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt upgrade
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Calculating upgrade... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-5.15.0-164 linux-headers-5.15.0-164-generic
# Use 'apt autoremove' to remove them.
# The following NEW packages will be installed:
#   linux-headers-5.15.0-171 linux-headers-5.15.0-171-generic
# The following packages will be upgraded:
#   cpp-11 curl g++-11 gcc-11 gcc-11-base gcc-12-base gfortran-11 gh git git-man
#   libasan6 libasound2 libasound2-data libatomic1 libavahi-client3
#   libavahi-common-data libavahi-common3 libc-bin libc-dev-bin libc6 libc6-dev
#   libcc1-0 libcurl3-gnutls libcurl4 libcurl4-openssl-dev libexpat1
#   libexpat1-dev libgcc-11-dev libgcc-s1 libgfortran-11-dev libgfortran5
#   libglib2.0-0 libglib2.0-bin libglib2.0-data libglib2.0-dev
#   libglib2.0-dev-bin libgnutls30 libgomp1 libitm1 libldap-2.5-0 liblsan0
#   libmysqlclient-dev libmysqlclient21 libpng-dev libpng16-16 libprotobuf23
#   libprotoc23 libpython3.10 libpython3.10-dev libpython3.10-minimal
#   libpython3.10-stdlib libpython3.12 libpython3.12-dev libpython3.12-stdlib
#   libquadmath0 libssh-4 libssh-gcrypt-4 libssl-dev libssl3 libstdc++-11-dev
#   libstdc++6 libtasn1-6 libtsan0 libubsan1 libvpx7 libxml2 libxml2-dev
#   libxnvctrl0 linux-headers-generic linux-libc-dev locales
#   openjdk-17-jdk-headless openjdk-17-jre-headless openssl protobuf-compiler
#   python3-pkg-resources python3.10 python3.10-minimal python3.12
#   python3.12-dev python3.12-tk r-cran-base64enc r-cran-broom r-cran-bslib
#   r-cran-cluster r-cran-cpp11 r-cran-data.table r-cran-dbi r-cran-dbplyr
#   r-cran-dplyr r-cran-dtplyr r-cran-foreign r-cran-gargle r-cran-ggplot2
#   r-cran-httr r-cran-later r-cran-lattice r-cran-lubridate r-cran-openssl
#   r-cran-pkgload r-cran-rappdirs r-cran-readr r-cran-shiny r-cran-timechange
#   r-cran-uuid r-cran-vctrs r-cran-viridislite r-cran-vroom r-cran-xfun
#   r-cran-xml2
# 110 upgraded, 2 newly installed, 0 to remove and 0 not upgraded.
# Need to get 314 MB of archives.
# After this operation, 105 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc6-dev amd64 2.35-0ubuntu3.13 [2,101 kB]
# Get:2 https://cli.github.com/packages stable/main amd64 gh amd64 2.87.3 [13.8 MB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ r-cran-foreign 0.8.91-1.2204.0 [250 kB]
# Get:4 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12-dev amd64 3.12.13-1+jammy1 [498 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-dev-bin amd64 2.35-0ubuntu3.13 [20.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 linux-libc-dev amd64 5.15.0-171.181 [1,316 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libatomic1 amd64 12.3.0-1ubuntu1~22.04.3 [10.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libubsan1 amd64 12.3.0-1ubuntu1~22.04.3 [976 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libquadmath0 amd64 12.3.0-1ubuntu1~22.04.3 [154 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liblsan0 amd64 12.3.0-1ubuntu1~22.04.3 [1,069 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libitm1 amd64 12.3.0-1ubuntu1~22.04.3 [30.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgomp1 amd64 12.3.0-1ubuntu1~22.04.3 [127 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgfortran5 amd64 12.3.0-1ubuntu1~22.04.3 [879 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12-base amd64 12.3.0-1ubuntu1~22.04.3 [216 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-s1 amd64 12.3.0-1ubuntu1~22.04.3 [53.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcc1-0 amd64 12.3.0-1ubuntu1~22.04.3 [48.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstdc++6 amd64 12.3.0-1ubuntu1~22.04.3 [699 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc6 amd64 2.35-0ubuntu3.13 [3,235 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-bin amd64 2.35-0ubuntu3.13 [706 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libexpat1-dev amd64 2.4.7-1ubuntu0.7 [148 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libexpat1 amd64 2.4.7-1ubuntu0.7 [92.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-dev amd64 3.10.12-1~22.04.14 [4,765 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10 amd64 3.10.12-1~22.04.14 [1,949 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl-dev amd64 3.0.2-0ubuntu1.21 [2,375 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssl3 amd64 3.0.2-0ubuntu1.21 [1,905 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10 amd64 3.10.12-1~22.04.14 [509 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-stdlib amd64 3.10.12-1~22.04.14 [1,850 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-minimal amd64 3.10.12-1~22.04.14 [2,275 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-minimal amd64 3.10.12-1~22.04.14 [816 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtasn1-6 amd64 4.18.0-4ubuntu0.2 [43.6 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgnutls30 amd64 3.7.3-4ubuntu1.8 [970 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev amd64 2.72.4-0ubuntu2.9 [1,744 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-dev-bin amd64 2.72.4-0ubuntu2.9 [117 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-data all 2.72.4-0ubuntu2.9 [5,088 B]
# Get:35 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-bin amd64 2.72.4-0ubuntu2.9 [80.9 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-0 amd64 2.72.4-0ubuntu2.9 [1,467 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2-dev amd64 2.9.13+dfsg-1ubuntu0.11 [805 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2 amd64 2.9.13+dfsg-1ubuntu0.11 [765 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 locales all 2.35-0ubuntu3.13 [4,248 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openssl amd64 3.0.2-0ubuntu1.21 [1,184 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpng-dev amd64 1.6.37-3ubuntu0.4 [193 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpng16-16 amd64 1.6.37-3ubuntu0.4 [192 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 g++-11 amd64 11.4.0-1ubuntu1~22.04.3 [11.4 MB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstdc++-11-dev amd64 11.4.0-1ubuntu1~22.04.3 [2,101 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gfortran-11 amd64 11.4.0-1ubuntu1~22.04.3 [11.2 MB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgfortran-11-dev amd64 11.4.0-1ubuntu1~22.04.3 [842 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasan6 amd64 11.4.0-1ubuntu1~22.04.3 [2,283 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-11 amd64 11.4.0-1ubuntu1~22.04.3 [20.1 MB]
# Get:49 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-base64enc amd64 0.1-6-1.ca2204.1 [29.4 kB]
# Get:50 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12-dev amd64 3.12.13-1+jammy1 [5,693 kB]
# Get:51 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-vctrs amd64 0.7.1-1.ca2204.1 [1,367 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-11-dev amd64 11.4.0-1ubuntu1~22.04.3 [2,517 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtsan0 amd64 11.4.0-1ubuntu1~22.04.3 [2,260 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cpp-11 amd64 11.4.0-1ubuntu1~22.04.3 [10.0 MB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-11-base amd64 11.4.0-1ubuntu1~22.04.3 [216 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4-openssl-dev amd64 7.81.0-1ubuntu1.22 [386 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libldap-2.5-0 amd64 2.5.20+dfsg-0ubuntu0.22.04.1 [184 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssh-4 amd64 0.9.6-2ubuntu0.22.04.6 [187 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 curl amd64 7.81.0-1ubuntu1.22 [194 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl4 amd64 7.81.0-1ubuntu1.22 [290 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl3-gnutls amd64 7.81.0-1ubuntu1.22 [284 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 git-man all 1:2.34.1-1ubuntu1.17 [954 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 git amd64 1:2.34.1-1ubuntu1.17 [3,174 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasound2 amd64 1.2.6.1-1ubuntu1.1 [391 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasound2-data all 1.2.6.1-1ubuntu1.1 [19.3 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-client3 amd64 0.8-5ubuntu5.4 [28.0 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-common3 amd64 0.8-5ubuntu5.4 [23.9 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-common-data amd64 0.8-5ubuntu5.4 [24.0 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmysqlclient-dev amd64 8.0.45-0ubuntu0.22.04.1 [1,703 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmysqlclient21 amd64 8.0.45-0ubuntu0.22.04.1 [1,308 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotobuf23 amd64 3.12.4-1ubuntu7.22.04.6 [877 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 protobuf-compiler amd64 3.12.4-1ubuntu7.22.04.6 [29.2 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libprotoc23 amd64 3.12.4-1ubuntu7.22.04.6 [662 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssh-gcrypt-4 amd64 0.9.6-2ubuntu0.22.04.6 [225 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libvpx7 amd64 1.11.0-2ubuntu2.5 [1,078 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxnvctrl0 amd64 510.47.03-0ubuntu1.22.04.1 [11.4 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 linux-headers-5.15.0-171 all 5.15.0-171.181 [12.4 MB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 linux-headers-5.15.0-171-generic amd64 5.15.0-171.181 [2,849 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 linux-headers-generic amd64 5.15.0.171.160 [2,332 B]
# Get:80 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jdk-headless amd64 17.0.18+8-1~22.04.1 [71.4 MB]
# Get:81 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-dplyr amd64 1.2.0-1.ca2204.1 [1,430 kB]
# Get:82 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-broom all 1.0.12-1.ca2204.1 [1,704 kB]
# Get:83 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-bslib all 0.10.0-1.ca2204.1 [5,335 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 openjdk-17-jre-headless amd64 17.0.18+8-1~22.04.1 [48.4 MB]
# Get:85 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-cluster amd64 2.1.8.2-1.ca2204.1 [568 kB]
# Get:86 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-cpp11 all 0.5.3-1.ca2204.1 [235 kB]
# Get:87 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-data.table amd64 1.18.2.1-1.ca2204.1 [2,533 kB]
# Get:88 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-dbi all 1.3.0-1.ca2204.1 [871 kB]
# Get:89 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-dbplyr all 2.5.2-1.ca2204.1 [1,219 kB]
# Get:90 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-dtplyr all 1.3.3-1.ca2204.1 [402 kB]
# Get:91 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-openssl amd64 2.3.5-1.ca2204.1 [633 kB]
# Get:92 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-httr all 1.4.8-1.ca2204.1 [471 kB]
# Get:93 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-rappdirs amd64 0.3.4-1.ca2204.1 [46.5 kB]
# Get:94 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-gargle all 1.6.1-1.ca2204.1 [717 kB]
# Get:95 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-ggplot2 all 4.0.2-1.ca2204.1 [7,819 kB]
# Get:96 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-later amd64 1.4.7-1.ca2204.1 [137 kB]
# Get:97 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-lattice amd64 0.22-9-1.ca2204.1 [1,401 kB]
# Get:98 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-timechange amd64 0.4.0-1.ca2204.1 [159 kB]
# Get:99 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-lubridate amd64 1.9.5-1.ca2204.1 [968 kB]
# Get:100 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-pkgload all 1.5.0-1.ca2204.1 [222 kB]
# Get:101 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-vroom amd64 1.7.0-1.ca2204.1 [904 kB]
# Get:102 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-readr amd64 2.2.0-1.ca2204.1 [773 kB]
# Get:103 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-shiny all 1.13.0-1.ca2204.1 [3,706 kB]
# Get:104 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-uuid amd64 1.2-2-1.ca2204.1 [48.6 kB]
# Get:105 https://r2u.stat.illinois.edu/ubuntu jammy/main all r-cran-viridislite all 0.4.3-1.ca2204.1 [1,297 kB]
# Get:106 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-xfun amd64 0.56-1.ca2204.1 [580 kB]
# Get:107 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 r-cran-xml2 amd64 1.5.2-1.ca2204.1 [270 kB]
# Get:108 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12 amd64 3.12.13-1+jammy1 [2,375 kB]
# Get:109 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12 amd64 3.12.13-1+jammy1 [2,517 kB]
# Get:110 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12-stdlib amd64 3.12.13-1+jammy1 [2,866 kB]
# Get:111 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-pkg-resources all 68.1.2-2~jammy3 [216 kB]
# Get:112 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12-tk amd64 3.12.13-1+jammy1 [153 kB]
# Fetched 314 MB in 9s (36.7 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../00-libc6-dev_2.35-0ubuntu3.13_amd64.deb ...
# Unpacking libc6-dev:amd64 (2.35-0ubuntu3.13) over (2.35-0ubuntu3.11) ...
# Preparing to unpack .../01-libc-dev-bin_2.35-0ubuntu3.13_amd64.deb ...
# Unpacking libc-dev-bin (2.35-0ubuntu3.13) over (2.35-0ubuntu3.11) ...
# Preparing to unpack .../02-linux-libc-dev_5.15.0-171.181_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (5.15.0-171.181) over (5.15.0-164.174) ...
# Preparing to unpack .../03-libatomic1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libatomic1:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../04-libubsan1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libubsan1:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../05-libquadmath0_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libquadmath0:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../06-liblsan0_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking liblsan0:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../07-libitm1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libitm1:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../08-libgomp1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgomp1:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../09-libgfortran5_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgfortran5:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../10-gcc-12-base_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking gcc-12-base:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Setting up gcc-12-base:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../libgcc-s1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgcc-s1:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Setting up libgcc-s1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../libcc1-0_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libcc1-0:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../libstdc++6_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libstdc++6:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04.2) ...
# Setting up libstdc++6:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../libc6_2.35-0ubuntu3.13_amd64.deb ...
# Unpacking libc6:amd64 (2.35-0ubuntu3.13) over (2.35-0ubuntu3.11) ...
# Setting up libc6:amd64 (2.35-0ubuntu3.13) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../libc-bin_2.35-0ubuntu3.13_amd64.deb ...
# Unpacking libc-bin (2.35-0ubuntu3.13) over (2.35-0ubuntu3.11) ...
# Setting up libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../0-libexpat1-dev_2.4.7-1ubuntu0.7_amd64.deb ...
# Unpacking libexpat1-dev:amd64 (2.4.7-1ubuntu0.7) over (2.4.7-1ubuntu0.6) ...
# Preparing to unpack .../1-libexpat1_2.4.7-1ubuntu0.7_amd64.deb ...
# Unpacking libexpat1:amd64 (2.4.7-1ubuntu0.7) over (2.4.7-1ubuntu0.6) ...
# Preparing to unpack .../2-libpython3.10-dev_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10-dev:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../3-libpython3.10_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../4-libssl-dev_3.0.2-0ubuntu1.21_amd64.deb ...
# Unpacking libssl-dev:amd64 (3.0.2-0ubuntu1.21) over (3.0.2-0ubuntu1.20) ...
# Preparing to unpack .../5-libssl3_3.0.2-0ubuntu1.21_amd64.deb ...
# Unpacking libssl3:amd64 (3.0.2-0ubuntu1.21) over (3.0.2-0ubuntu1.20) ...
# Setting up libssl3:amd64 (3.0.2-0ubuntu1.21) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../python3.10_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../libpython3.10-stdlib_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10-stdlib:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../python3.10-minimal_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10-minimal (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../libpython3.10-minimal_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10-minimal:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../libtasn1-6_4.18.0-4ubuntu0.2_amd64.deb ...
# Unpacking libtasn1-6:amd64 (4.18.0-4ubuntu0.2) over (4.18.0-4ubuntu0.1) ...
# Setting up libtasn1-6:amd64 (4.18.0-4ubuntu0.2) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../libgnutls30_3.7.3-4ubuntu1.8_amd64.deb ...
# Unpacking libgnutls30:amd64 (3.7.3-4ubuntu1.8) over (3.7.3-4ubuntu1.7) ...
# Setting up libgnutls30:amd64 (3.7.3-4ubuntu1.8) ...
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../00-libglib2.0-dev_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.7) ...
# Preparing to unpack .../01-libglib2.0-dev-bin_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.7) ...
# Preparing to unpack .../02-libglib2.0-data_2.72.4-0ubuntu2.9_all.deb ...
# Unpacking libglib2.0-data (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.7) ...
# Preparing to unpack .../03-libglib2.0-bin_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.7) ...
# Preparing to unpack .../04-libglib2.0-0_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.7) ...
# Preparing to unpack .../05-libxml2-dev_2.9.13+dfsg-1ubuntu0.11_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.13+dfsg-1ubuntu0.11) over (2.9.13+dfsg-1ubuntu0.10) ...
# Preparing to unpack .../06-libxml2_2.9.13+dfsg-1ubuntu0.11_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.13+dfsg-1ubuntu0.11) over (2.9.13+dfsg-1ubuntu0.10) ...
# Preparing to unpack .../07-locales_2.35-0ubuntu3.13_all.deb ...
# Unpacking locales (2.35-0ubuntu3.13) over (2.35-0ubuntu3.11) ...
# Preparing to unpack .../08-openssl_3.0.2-0ubuntu1.21_amd64.deb ...
# Unpacking openssl (3.0.2-0ubuntu1.21) over (3.0.2-0ubuntu1.20) ...
# Preparing to unpack .../09-libpng-dev_1.6.37-3ubuntu0.4_amd64.deb ...
# Unpacking libpng-dev:amd64 (1.6.37-3ubuntu0.4) over (1.6.37-3ubuntu0.3) ...
# Preparing to unpack .../10-libpng16-16_1.6.37-3ubuntu0.4_amd64.deb ...
# Unpacking libpng16-16:amd64 (1.6.37-3ubuntu0.4) over (1.6.37-3ubuntu0.3) ...
# Preparing to unpack .../11-g++-11_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking g++-11 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../12-libstdc++-11-dev_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libstdc++-11-dev:amd64 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../13-gfortran-11_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking gfortran-11 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../14-libgfortran-11-dev_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgfortran-11-dev:amd64 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../15-libasan6_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libasan6:amd64 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../16-gcc-11_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking gcc-11 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../17-libgcc-11-dev_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgcc-11-dev:amd64 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../18-libtsan0_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libtsan0:amd64 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../19-cpp-11_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking cpp-11 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../20-gcc-11-base_11.4.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking gcc-11-base:amd64 (11.4.0-1ubuntu1~22.04.3) over (11.4.0-1ubuntu1~22.04.2) ...
# Preparing to unpack .../21-libcurl4-openssl-dev_7.81.0-1ubuntu1.22_amd64.deb ...
# Unpacking libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.22) over (7.81.0-1ubuntu1.21) ...
# Preparing to unpack .../22-libldap-2.5-0_2.5.20+dfsg-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libldap-2.5-0:amd64 (2.5.20+dfsg-0ubuntu0.22.04.1) over (2.5.19+dfsg-0ubuntu0.22.04.1) ...
# Preparing to unpack .../23-libssh-4_0.9.6-2ubuntu0.22.04.6_amd64.deb ...
# Unpacking libssh-4:amd64 (0.9.6-2ubuntu0.22.04.6) over (0.9.6-2ubuntu0.22.04.5) ...
# Preparing to unpack .../24-curl_7.81.0-1ubuntu1.22_amd64.deb ...
# Unpacking curl (7.81.0-1ubuntu1.22) over (7.81.0-1ubuntu1.21) ...
# Preparing to unpack .../25-libcurl4_7.81.0-1ubuntu1.22_amd64.deb ...
# Unpacking libcurl4:amd64 (7.81.0-1ubuntu1.22) over (7.81.0-1ubuntu1.21) ...
# Preparing to unpack .../26-libcurl3-gnutls_7.81.0-1ubuntu1.22_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.81.0-1ubuntu1.22) over (7.81.0-1ubuntu1.21) ...
# Preparing to unpack .../27-git-man_1%3a2.34.1-1ubuntu1.17_all.deb ...
# Unpacking git-man (1:2.34.1-1ubuntu1.17) over (1:2.34.1-1ubuntu1.15) ...
# Preparing to unpack .../28-git_1%3a2.34.1-1ubuntu1.17_amd64.deb ...
# Unpacking git (1:2.34.1-1ubuntu1.17) over (1:2.34.1-1ubuntu1.15) ...
# Preparing to unpack .../29-gh_2.87.3_amd64.deb ...
# Unpacking gh (2.87.3) over (2.85.0) ...
# Preparing to unpack .../30-libasound2_1.2.6.1-1ubuntu1.1_amd64.deb ...
# Unpacking libasound2:amd64 (1.2.6.1-1ubuntu1.1) over (1.2.6.1-1ubuntu1) ...
# Preparing to unpack .../31-libasound2-data_1.2.6.1-1ubuntu1.1_all.deb ...
# Unpacking libasound2-data (1.2.6.1-1ubuntu1.1) over (1.2.6.1-1ubuntu1) ...
# Preparing to unpack .../32-libavahi-client3_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking libavahi-client3:amd64 (0.8-5ubuntu5.4) over (0.8-5ubuntu5.3) ...
# Preparing to unpack .../33-libavahi-common3_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking libavahi-common3:amd64 (0.8-5ubuntu5.4) over (0.8-5ubuntu5.3) ...
# Preparing to unpack .../34-libavahi-common-data_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking libavahi-common-data:amd64 (0.8-5ubuntu5.4) over (0.8-5ubuntu5.3) ...
# Preparing to unpack .../35-libmysqlclient-dev_8.0.45-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libmysqlclient-dev (8.0.45-0ubuntu0.22.04.1) over (8.0.44-0ubuntu0.22.04.2) ...
# Preparing to unpack .../36-libmysqlclient21_8.0.45-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libmysqlclient21:amd64 (8.0.45-0ubuntu0.22.04.1) over (8.0.44-0ubuntu0.22.04.2) ...
# Preparing to unpack .../37-libprotobuf23_3.12.4-1ubuntu7.22.04.6_amd64.deb ...
# Unpacking libprotobuf23:amd64 (3.12.4-1ubuntu7.22.04.6) over (3.12.4-1ubuntu7.22.04.4) ...
# Preparing to unpack .../38-protobuf-compiler_3.12.4-1ubuntu7.22.04.6_amd64.deb ...
# Unpacking protobuf-compiler (3.12.4-1ubuntu7.22.04.6) over (3.12.4-1ubuntu7.22.04.4) ...
# Preparing to unpack .../39-libprotoc23_3.12.4-1ubuntu7.22.04.6_amd64.deb ...
# Unpacking libprotoc23:amd64 (3.12.4-1ubuntu7.22.04.6) over (3.12.4-1ubuntu7.22.04.4) ...
# Preparing to unpack .../40-python3.12-dev_3.12.13-1+jammy1_amd64.deb ...
# Unpacking python3.12-dev (3.12.13-1+jammy1) over (3.12.12-1+jammy1) ...
# Preparing to unpack .../41-libpython3.12-dev_3.12.13-1+jammy1_amd64.deb ...
# Unpacking libpython3.12-dev:amd64 (3.12.13-1+jammy1) over (3.12.12-1+jammy1) ...
# Preparing to unpack .../42-libpython3.12_3.12.13-1+jammy1_amd64.deb ...
# Unpacking libpython3.12:amd64 (3.12.13-1+jammy1) over (3.12.12-1+jammy1) ...
# Preparing to unpack .../43-python3.12_3.12.13-1+jammy1_amd64.deb ...
# Unpacking python3.12 (3.12.13-1+jammy1) over (3.12.12-1+jammy1) ...
# Preparing to unpack .../44-libpython3.12-stdlib_3.12.13-1+jammy1_amd64.deb ...
# Unpacking libpython3.12-stdlib:amd64 (3.12.13-1+jammy1) over (3.12.12-1+jammy1) ...
# Preparing to unpack .../45-libssh-gcrypt-4_0.9.6-2ubuntu0.22.04.6_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.6) over (0.9.6-2ubuntu0.22.04.5) ...
# Preparing to unpack .../46-libvpx7_1.11.0-2ubuntu2.5_amd64.deb ...
# Unpacking libvpx7:amd64 (1.11.0-2ubuntu2.5) over (1.11.0-2ubuntu2.4) ...
# Preparing to unpack .../47-libxnvctrl0_510.47.03-0ubuntu1.22.04.1_amd64.deb ...
# Unpacking libxnvctrl0:amd64 (510.47.03-0ubuntu1.22.04.1) over (510.47.03-0ubuntu1) ...
# Selecting previously unselected package linux-headers-5.15.0-171.
# Preparing to unpack .../48-linux-headers-5.15.0-171_5.15.0-171.181_all.deb ...
# Unpacking linux-headers-5.15.0-171 (5.15.0-171.181) ...
# Selecting previously unselected package linux-headers-5.15.0-171-generic.
# Preparing to unpack .../49-linux-headers-5.15.0-171-generic_5.15.0-171.181_amd64.deb ...
# Unpacking linux-headers-5.15.0-171-generic (5.15.0-171.181) ...
# Preparing to unpack .../50-linux-headers-generic_5.15.0.171.160_amd64.deb ...
# Unpacking linux-headers-generic (5.15.0.171.160) over (5.15.0.164.159) ...
# Preparing to unpack .../51-openjdk-17-jdk-headless_17.0.18+8-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jdk-headless:amd64 (17.0.18+8-1~22.04.1) over (17.0.17+10-1~22.04) ...
# Preparing to unpack .../52-openjdk-17-jre-headless_17.0.18+8-1~22.04.1_amd64.deb ...
# Unpacking openjdk-17-jre-headless:amd64 (17.0.18+8-1~22.04.1) over (17.0.17+10-1~22.04) ...
# Preparing to unpack .../53-python3-pkg-resources_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-pkg-resources (68.1.2-2~jammy3) over (59.6.0-1.2ubuntu0.22.04.3) ...
# Preparing to unpack .../54-python3.12-tk_3.12.13-1+jammy1_amd64.deb ...
# Unpacking python3.12-tk:amd64 (3.12.13-1+jammy1) over (3.12.12-1+jammy1) ...
# Preparing to unpack .../55-r-cran-base64enc_0.1-6-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-base64enc (0.1-6-1.ca2204.1) over (0.1-3-3) ...
# Preparing to unpack .../56-r-cran-vctrs_0.7.1-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-vctrs (0.7.1-1.ca2204.1) over (0.7.0-1.ca2204.1) ...
# Preparing to unpack .../57-r-cran-dplyr_1.2.0-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-dplyr (1.2.0-1.ca2204.1) over (1.1.4-1.ca2204.1) ...
# Preparing to unpack .../58-r-cran-broom_1.0.12-1.ca2204.1_all.deb ...
# Unpacking r-cran-broom (1.0.12-1.ca2204.1) over (1.0.11-1.ca2204.1) ...
# Preparing to unpack .../59-r-cran-bslib_0.10.0-1.ca2204.1_all.deb ...
# Unpacking r-cran-bslib (0.10.0-1.ca2204.1) over (0.9.0-1.ca2204.1) ...
# Preparing to unpack .../60-r-cran-cluster_2.1.8.2-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-cluster (2.1.8.2-1.ca2204.1) over (2.1.8.1-1.ca2204.1) ...
# Preparing to unpack .../61-r-cran-cpp11_0.5.3-1.ca2204.1_all.deb ...
# Unpacking r-cran-cpp11 (0.5.3-1.ca2204.1) over (0.5.2-1.ca2204.1) ...
# Preparing to unpack .../62-r-cran-data.table_1.18.2.1-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-data.table (1.18.2.1-1.ca2204.1) over (1.18.0-1.ca2204.1) ...
# Preparing to unpack .../63-r-cran-dbi_1.3.0-1.ca2204.1_all.deb ...
# Unpacking r-cran-dbi (1.3.0-1.ca2204.1) over (1.2.3-1.ca2204.1) ...
# Preparing to unpack .../64-r-cran-dbplyr_2.5.2-1.ca2204.1_all.deb ...
# Unpacking r-cran-dbplyr (2.5.2-1.ca2204.1) over (2.5.1-1.ca2204.1) ...
# Preparing to unpack .../65-r-cran-dtplyr_1.3.3-1.ca2204.1_all.deb ...
# Unpacking r-cran-dtplyr (1.3.3-1.ca2204.1) over (1.3.2-1.ca2204.1) ...
# Preparing to unpack .../66-r-cran-foreign_0.8.91-1.2204.0_amd64.deb ...
# Unpacking r-cran-foreign (0.8.91-1.2204.0) over (0.8.90-1.ca2204.1) ...
# Preparing to unpack .../67-r-cran-openssl_2.3.5-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-openssl (2.3.5-1.ca2204.1) over (2.3.4-1.ca2204.1) ...
# Preparing to unpack .../68-r-cran-httr_1.4.8-1.ca2204.1_all.deb ...
# Unpacking r-cran-httr (1.4.8-1.ca2204.1) over (1.4.7-1.ca2204.1) ...
# Preparing to unpack .../69-r-cran-rappdirs_0.3.4-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-rappdirs (0.3.4-1.ca2204.1) over (0.3.3-1.ca2204.1) ...
# Preparing to unpack .../70-r-cran-gargle_1.6.1-1.ca2204.1_all.deb ...
# Unpacking r-cran-gargle (1.6.1-1.ca2204.1) over (1.6.0-1.ca2204.1) ...
# Preparing to unpack .../71-r-cran-ggplot2_4.0.2-1.ca2204.1_all.deb ...
# Unpacking r-cran-ggplot2 (4.0.2-1.ca2204.1) over (4.0.1-1.ca2204.1) ...
# Preparing to unpack .../72-r-cran-later_1.4.7-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-later (1.4.7-1.ca2204.1) over (1.4.5-1.ca2204.1) ...
# Preparing to unpack .../73-r-cran-lattice_0.22-9-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-lattice (0.22-9-1.ca2204.1) over (0.22-7-1.ca2204.1) ...
# Preparing to unpack .../74-r-cran-timechange_0.4.0-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-timechange (0.4.0-1.ca2204.1) over (0.3.0-1.ca2204.1) ...
# Preparing to unpack .../75-r-cran-lubridate_1.9.5-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-lubridate (1.9.5-1.ca2204.1) over (1.9.4-1.ca2204.1) ...
# Preparing to unpack .../76-r-cran-pkgload_1.5.0-1.ca2204.1_all.deb ...
# Unpacking r-cran-pkgload (1.5.0-1.ca2204.1) over (1.4.1-1.ca2204.1) ...
# Preparing to unpack .../77-r-cran-vroom_1.7.0-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-vroom (1.7.0-1.ca2204.1) over (1.6.7-1.ca2204.1) ...
# Preparing to unpack .../78-r-cran-readr_2.2.0-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-readr (2.2.0-1.ca2204.1) over (2.1.6-1.ca2204.1) ...
# Preparing to unpack .../79-r-cran-shiny_1.13.0-1.ca2204.1_all.deb ...
# Unpacking r-cran-shiny (1.13.0-1.ca2204.1) over (1.12.1-1.ca2204.1) ...
# Preparing to unpack .../80-r-cran-uuid_1.2-2-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-uuid (1.2-2-1.ca2204.1) over (1.2-1-1.ca2204.1) ...
# Preparing to unpack .../81-r-cran-viridislite_0.4.3-1.ca2204.1_all.deb ...
# Unpacking r-cran-viridislite (0.4.3-1.ca2204.1) over (0.4.2-1.ca2204.1) ...
# Preparing to unpack .../82-r-cran-xfun_0.56-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-xfun (0.56-1.ca2204.1) over (0.55-1.ca2204.1) ...
# Preparing to unpack .../83-r-cran-xml2_1.5.2-1.ca2204.1_amd64.deb ...
# Unpacking r-cran-xml2 (1.5.2-1.ca2204.1) over (1.5.1-1.ca2204.1) ...
# Setting up python3-pkg-resources (68.1.2-2~jammy3) ...
# Setting up libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.6) ...
# Setting up libexpat1:amd64 (2.4.7-1ubuntu0.7) ...
# Setting up gcc-11-base:amd64 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up r-cran-openssl (2.3.5-1.ca2204.1) ...
# Setting up r-cran-pkgload (1.5.0-1.ca2204.1) ...
# Setting up libmysqlclient21:amd64 (8.0.45-0ubuntu0.22.04.1) ...
# Setting up libpython3.12-stdlib:amd64 (3.12.13-1+jammy1) ...
# Setting up r-cran-uuid (1.2-2-1.ca2204.1) ...
# Setting up r-cran-xfun (0.56-1.ca2204.1) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up r-cran-base64enc (0.1-6-1.ca2204.1) ...
# Setting up python3.12 (3.12.13-1+jammy1) ...
# Setting up python3.12-tk:amd64 (3.12.13-1+jammy1) ...
# Setting up r-cran-dbi (1.3.0-1.ca2204.1) ...
# Setting up linux-libc-dev:amd64 (5.15.0-171.181) ...
# Setting up libprotobuf23:amd64 (3.12.4-1ubuntu7.22.04.6) ...
# Setting up libgomp1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up r-cran-data.table (1.18.2.1-1.ca2204.1) ...
# Setting up r-cran-foreign (0.8.91-1.2204.0) ...
# Setting up locales (2.35-0ubuntu3.13) ...
# Generating locales (this might take a while)...
#   en_US.UTF-8... done
# Generation complete.
# Setting up libldap-2.5-0:amd64 (2.5.20+dfsg-0ubuntu0.22.04.1) ...
# Setting up libasan6:amd64 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up libxnvctrl0:amd64 (510.47.03-0ubuntu1.22.04.1) ...
# Setting up libasound2-data (1.2.6.1-1ubuntu1.1) ...
# Setting up libglib2.0-data (2.72.4-0ubuntu2.9) ...
# Setting up r-cran-bslib (0.10.0-1.ca2204.1) ...
# Setting up r-cran-httr (1.4.8-1.ca2204.1) ...
# Setting up r-cran-cpp11 (0.5.3-1.ca2204.1) ...
# Setting up libprotoc23:amd64 (3.12.4-1ubuntu7.22.04.6) ...
# Setting up libavahi-common-data:amd64 (0.8-5ubuntu5.4) ...
# Setting up libquadmath0:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up libssl-dev:amd64 (3.0.2-0ubuntu1.21) ...
# Setting up libpng16-16:amd64 (1.6.37-3ubuntu0.4) ...
# Setting up libatomic1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up libpython3.10-minimal:amd64 (3.10.12-1~22.04.14) ...
# Setting up r-cran-later (1.4.7-1.ca2204.1) ...
# Setting up r-cran-lattice (0.22-9-1.ca2204.1) ...
# Setting up libssh-4:amd64 (0.9.6-2ubuntu0.22.04.6) ...
# Setting up libgfortran5:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up linux-headers-5.15.0-171 (5.15.0-171.181) ...
# Setting up libubsan1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up linux-headers-5.15.0-171-generic (5.15.0-171.181) ...
# Setting up r-cran-viridislite (0.4.3-1.ca2204.1) ...
# Setting up r-cran-cluster (2.1.8.2-1.ca2204.1) ...
# Setting up libasound2:amd64 (1.2.6.1-1ubuntu1.1) ...
# Setting up libcurl4:amd64 (7.81.0-1ubuntu1.22) ...
# Setting up git-man (1:2.34.1-1ubuntu1.17) ...
# Setting up libvpx7:amd64 (1.11.0-2ubuntu2.5) ...
# Setting up curl (7.81.0-1ubuntu1.22) ...
# Setting up libc-dev-bin (2.35-0ubuntu3.13) ...
# Setting up openssl (3.0.2-0ubuntu1.21) ...
# Setting up libxml2:amd64 (2.9.13+dfsg-1ubuntu0.11) ...
# Setting up libpython3.12:amd64 (3.12.13-1+jammy1) ...
# Setting up libcc1-0:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up r-cran-vctrs (0.7.1-1.ca2204.1) ...
# Setting up r-cran-rappdirs (0.3.4-1.ca2204.1) ...
# Setting up liblsan0:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up libitm1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up libmysqlclient-dev (8.0.45-0ubuntu0.22.04.1) ...
# Setting up libtsan0:amd64 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up cpp-11 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.9) ...
# Setting up r-cran-gargle (1.6.1-1.ca2204.1) ...
# Setting up r-cran-vroom (1.7.0-1.ca2204.1) ...
# Setting up protobuf-compiler (3.12.4-1ubuntu7.22.04.6) ...
# Setting up r-cran-ggplot2 (4.0.2-1.ca2204.1) ...
# Setting up r-cran-xml2 (1.5.2-1.ca2204.1) ...
# Setting up libpng-dev:amd64 (1.6.37-3ubuntu0.4) ...
# Setting up libavahi-common3:amd64 (0.8-5ubuntu5.4) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.9) ...
# Setting up libcurl3-gnutls:amd64 (7.81.0-1ubuntu1.22) ...
# Setting up r-cran-shiny (1.13.0-1.ca2204.1) ...
# Setting up linux-headers-generic (5.15.0.171.160) ...
# Setting up python3.10-minimal (3.10.12-1~22.04.14) ...
# Setting up libpython3.10-stdlib:amd64 (3.10.12-1~22.04.14) ...
# Setting up libxml2-dev:amd64 (2.9.13+dfsg-1ubuntu0.11) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up r-cran-timechange (0.4.0-1.ca2204.1) ...
# Setting up libcurl4-openssl-dev:amd64 (7.81.0-1ubuntu1.22) ...
# Setting up r-cran-readr (2.2.0-1.ca2204.1) ...
# Setting up git (1:2.34.1-1ubuntu1.17) ...
# Setting up openjdk-17-jre-headless:amd64 (17.0.18+8-1~22.04.1) ...
# Installing new version of config file /etc/java-17-openjdk/jfr/default.jfc ...
# Installing new version of config file /etc/java-17-openjdk/security/java.security ...
# Setting up libgcc-11-dev:amd64 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up gcc-11 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up libc6-dev:amd64 (2.35-0ubuntu3.13) ...
# Setting up r-cran-dplyr (1.2.0-1.ca2204.1) ...
# Setting up r-cran-dbplyr (2.5.2-1.ca2204.1) ...
# Setting up libavahi-client3:amd64 (0.8-5ubuntu5.4) ...
# Setting up r-cran-lubridate (1.9.5-1.ca2204.1) ...
# Setting up libpython3.10:amd64 (3.10.12-1~22.04.14) ...
# Setting up python3.10 (3.10.12-1~22.04.14) ...
# Setting up libgfortran-11-dev:amd64 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up r-cran-dtplyr (1.3.3-1.ca2204.1) ...
# Setting up libexpat1-dev:amd64 (2.4.7-1ubuntu0.7) ...
# Setting up r-cran-broom (1.0.12-1.ca2204.1) ...
# Setting up openjdk-17-jdk-headless:amd64 (17.0.18+8-1~22.04.1) ...
# Setting up libpython3.10-dev:amd64 (3.10.12-1~22.04.14) ...
# Setting up gh (2.87.3) ...
# Setting up gfortran-11 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up libstdc++-11-dev:amd64 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up g++-11 (11.4.0-1ubuntu1~22.04.3) ...
# Setting up libpython3.12-dev:amd64 (3.12.13-1+jammy1) ...
# Setting up python3.12-dev (3.12.13-1+jammy1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...

# %%
# !pip install -q ydata-profiling
# !apt-get -qq install -y wkhtmltopdf
# !pip install -q pdfkit


# Step 3: Import and creating DataFrame
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
import pdfkit
import os
config = pdfkit.configuration(wkhtmltopdf="/usr/bin/wkhtmltopdf") # Configure PDFKit

# Step 4:Convert HTML to PDF
pdfkit.from_file("report.html", "report.pdf", configuration=config)

# Step 5: Download the PDF
from google.colab import files
files.download("report.pdf")
# Out:
# Extracting templates from packages: 100%
# Selecting previously unselected package libavahi-core7:amd64.
# (Reading database ... 145972 files and directories currently installed.)
# Preparing to unpack .../00-libavahi-core7_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking libavahi-core7:amd64 (0.8-5ubuntu5.4) ...
# Selecting previously unselected package libdaemon0:amd64.
# Preparing to unpack .../01-libdaemon0_0.14-7.1ubuntu3_amd64.deb ...
# Unpacking libdaemon0:amd64 (0.14-7.1ubuntu3) ...
# Selecting previously unselected package avahi-daemon.
# Preparing to unpack .../02-avahi-daemon_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking avahi-daemon (0.8-5ubuntu5.4) ...
# Selecting previously unselected package libdouble-conversion3:amd64.
# Preparing to unpack .../03-libdouble-conversion3_3.1.7-4_amd64.deb ...
# Unpacking libdouble-conversion3:amd64 (3.1.7-4) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../04-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../05-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../06-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../07-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../08-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../09-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../10-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../11-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../12-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../13-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../14-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../15-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../16-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../17-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../18-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../19-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../20-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../21-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../22-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../23-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../24-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../25-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../26-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../27-liborc-0.4-0_1%3a0.4.32-2ubuntu0.1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../28-libgstreamer-plugins-base1.0-0_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../29-libhyphen0_2.8.8-7build2_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-7build2) ...
# Selecting previously unselected package libqt5positioning5:amd64.
# Preparing to unpack .../30-libqt5positioning5_5.15.3+dfsg-3_amd64.deb ...
# Unpacking libqt5positioning5:amd64 (5.15.3+dfsg-3) ...
# Selecting previously unselected package libqt5printsupport5:amd64.
# Preparing to unpack .../31-libqt5printsupport5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5printsupport5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5qml5:amd64.
# Preparing to unpack .../32-libqt5qml5_5.15.3+dfsg-1_amd64.deb ...
# Unpacking libqt5qml5:amd64 (5.15.3+dfsg-1) ...
# Selecting previously unselected package libqt5qmlmodels5:amd64.
# Preparing to unpack .../33-libqt5qmlmodels5_5.15.3+dfsg-1_amd64.deb ...
# Unpacking libqt5qmlmodels5:amd64 (5.15.3+dfsg-1) ...
# Selecting previously unselected package libqt5quick5:amd64.
# Preparing to unpack .../34-libqt5quick5_5.15.3+dfsg-1_amd64.deb ...
# Unpacking libqt5quick5:amd64 (5.15.3+dfsg-1) ...
# Selecting previously unselected package libqt5sensors5:amd64.
# Preparing to unpack .../35-libqt5sensors5_5.15.3-1_amd64.deb ...
# Unpacking libqt5sensors5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libqt5webchannel5:amd64.
# Preparing to unpack .../36-libqt5webchannel5_5.15.3-1_amd64.deb ...
# Unpacking libqt5webchannel5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../37-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Selecting previously unselected package libqt5webkit5:amd64.
# Preparing to unpack .../38-libqt5webkit5_5.212.0~alpha4-15ubuntu1_amd64.deb ...
# Unpacking libqt5webkit5:amd64 (5.212.0~alpha4-15ubuntu1) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../39-udev_249.11-0ubuntu3.17_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.17) ...
# Selecting previously unselected package libatspi2.0-0:amd64.
# Preparing to unpack .../40-libatspi2.0-0_2.44.0-3_amd64.deb ...
# Unpacking libatspi2.0-0:amd64 (2.44.0-3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../41-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../42-session-migration_0.3.6_amd64.deb ...
# Unpacking session-migration (0.3.6) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../43-gsettings-desktop-schemas_42.0-1ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../44-at-spi2-core_2.44.0-3_amd64.deb ...
# Unpacking at-spi2-core (2.44.0-3) ...
# Selecting previously unselected package libavahi-glib1:amd64.
# Preparing to unpack .../45-libavahi-glib1_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking libavahi-glib1:amd64 (0.8-5ubuntu5.4) ...
# Selecting previously unselected package libjson-glib-1.0-common.
# Preparing to unpack .../46-libjson-glib-1.0-common_1.6.6-1build1_all.deb ...
# Unpacking libjson-glib-1.0-common (1.6.6-1build1) ...
# Selecting previously unselected package libjson-glib-1.0-0:amd64.
# Preparing to unpack .../47-libjson-glib-1.0-0_1.6.6-1build1_amd64.deb ...
# Unpacking libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Selecting previously unselected package libmm-glib0:amd64.
# Preparing to unpack .../48-libmm-glib0_1.20.0-1~ubuntu22.04.4_amd64.deb ...
# Unpacking libmm-glib0:amd64 (1.20.0-1~ubuntu22.04.4) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../49-libnotify4_0.7.9-3ubuntu5.22.04.1_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Selecting previously unselected package libproxy1v5:amd64.
# Preparing to unpack .../50-libproxy1v5_0.4.17-2_amd64.deb ...
# Unpacking libproxy1v5:amd64 (0.4.17-2) ...
# Selecting previously unselected package glib-networking-common.
# Preparing to unpack .../51-glib-networking-common_2.72.0-1_all.deb ...
# Unpacking glib-networking-common (2.72.0-1) ...
# Selecting previously unselected package glib-networking-services.
# Preparing to unpack .../52-glib-networking-services_2.72.0-1_amd64.deb ...
# Unpacking glib-networking-services (2.72.0-1) ...
# Selecting previously unselected package glib-networking:amd64.
# Preparing to unpack .../53-glib-networking_2.72.0-1_amd64.deb ...
# Unpacking glib-networking:amd64 (2.72.0-1) ...
# Selecting previously unselected package libsoup2.4-common.
# Preparing to unpack .../54-libsoup2.4-common_2.74.2-3ubuntu0.6_all.deb ...
# Unpacking libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package libsoup2.4-1:amd64.
# Preparing to unpack .../55-libsoup2.4-1_2.74.2-3ubuntu0.6_amd64.deb ...
# Unpacking libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Selecting previously unselected package geoclue-2.0.
# Preparing to unpack .../56-geoclue-2.0_2.5.7-3ubuntu3_amd64.deb ...
# Unpacking geoclue-2.0 (2.5.7-3ubuntu3) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../57-libcdparanoia0_3.10.2+debian-14build2_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../58-libvisual-0.4-0_0.4.0-17build2_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../59-gstreamer1.0-plugins-base_1.20.1-1ubuntu0.5_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Selecting previously unselected package iio-sensor-proxy.
# Preparing to unpack .../60-iio-sensor-proxy_3.3-0ubuntu6_amd64.deb ...
# Unpacking iio-sensor-proxy (3.3-0ubuntu6) ...
# Selecting previously unselected package libatk1.0-data.
# Preparing to unpack .../61-libatk1.0-data_2.36.0-3build1_all.deb ...
# Unpacking libatk1.0-data (2.36.0-3build1) ...
# Selecting previously unselected package libatk1.0-0:amd64.
# Preparing to unpack .../62-libatk1.0-0_2.36.0-3build1_amd64.deb ...
# Unpacking libatk1.0-0:amd64 (2.36.0-3build1) ...
# Selecting previously unselected package libatk-bridge2.0-0:amd64.
# Preparing to unpack .../63-libatk-bridge2.0-0_2.38.0-3_amd64.deb ...
# Unpacking libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Selecting previously unselected package libxcomposite1:amd64.
# Preparing to unpack .../64-libxcomposite1_1%3a0.4.5-1build2_amd64.deb ...
# Unpacking libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Selecting previously unselected package libgtk-3-common.
# Preparing to unpack .../65-libgtk-3-common_3.24.33-1ubuntu2.2_all.deb ...
# Unpacking libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-0:amd64.
# Preparing to unpack .../66-libgtk-3-0_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libgtk-3-bin.
# Preparing to unpack .../67-libgtk-3-bin_3.24.33-1ubuntu2.2_amd64.deb ...
# Unpacking libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Selecting previously unselected package libmbim-glib4:amd64.
# Preparing to unpack .../68-libmbim-glib4_1.28.0-1~ubuntu20.04.2_amd64.deb ...
# Unpacking libmbim-glib4:amd64 (1.28.0-1~ubuntu20.04.2) ...
# Selecting previously unselected package libmbim-proxy.
# Preparing to unpack .../69-libmbim-proxy_1.28.0-1~ubuntu20.04.2_amd64.deb ...
# Unpacking libmbim-proxy (1.28.0-1~ubuntu20.04.2) ...
# Selecting previously unselected package libnl-genl-3-200:amd64.
# Preparing to unpack .../70-libnl-genl-3-200_3.5.0-0.1_amd64.deb ...
# Unpacking libnl-genl-3-200:amd64 (3.5.0-0.1) ...
# Selecting previously unselected package libnss-mdns:amd64.
# Preparing to unpack .../71-libnss-mdns_0.15.1-1ubuntu1_amd64.deb ...
# Unpacking libnss-mdns:amd64 (0.15.1-1ubuntu1) ...
# Selecting previously unselected package libqmi-glib5:amd64.
# Preparing to unpack .../72-libqmi-glib5_1.32.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libqmi-glib5:amd64 (1.32.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libqmi-proxy.
# Preparing to unpack .../73-libqmi-proxy_1.32.0-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libqmi-proxy (1.32.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package librsvg2-common:amd64.
# Preparing to unpack .../74-librsvg2-common_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../75-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package modemmanager.
# Preparing to unpack .../76-modemmanager_1.20.0-1~ubuntu22.04.4_amd64.deb ...
# Unpacking modemmanager (1.20.0-1~ubuntu22.04.4) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../77-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../78-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../79-systemd-hwe-hwdb_249.11.6_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.6) ...
# Selecting previously unselected package wpasupplicant.
# Preparing to unpack .../80-wpasupplicant_2%3a2.10-6ubuntu2.4_amd64.deb ...
# Unpacking wpasupplicant (2:2.10-6ubuntu2.4) ...
# Selecting previously unselected package usb-modeswitch-data.
# Preparing to unpack .../81-usb-modeswitch-data_20191128-4_all.deb ...
# Unpacking usb-modeswitch-data (20191128-4) ...
# Selecting previously unselected package usb-modeswitch.
# Preparing to unpack .../82-usb-modeswitch_2.6.1-3ubuntu2_amd64.deb ...
# Unpacking usb-modeswitch (2.6.1-3ubuntu2) ...
# Selecting previously unselected package wkhtmltopdf.
# Preparing to unpack .../83-wkhtmltopdf_0.12.6-2_amd64.deb ...
# Unpacking wkhtmltopdf (0.12.6-2) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdouble-conversion3:amd64 (3.1.7-4) ...
# Setting up libproxy1v5:amd64 (0.4.17-2) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up usb-modeswitch-data (20191128-4) ...
# Setting up udev (249.11-0ubuntu3.17) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libsoup2.4-common (2.74.2-3ubuntu0.6) ...
# Setting up systemd-hwe-hwdb (249.11.6) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libmm-glib0:amd64 (1.20.0-1~ubuntu22.04.4) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libnl-genl-3-200:amd64 (3.5.0-0.1) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libavahi-glib1:amd64 (0.8-5ubuntu5.4) ...
# Setting up libjson-glib-1.0-common (1.6.6-1build1) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up usb-modeswitch (2.6.1-3ubuntu2) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up libqt5sensors5:amd64 (5.15.3-1) ...
# Setting up libdaemon0:amd64 (0.14-7.1ubuntu3) ...
# Setting up libavahi-core7:amd64 (0.8-5ubuntu5.4) ...
# Setting up libnss-mdns:amd64 (0.15.1-1ubuntu1) ...
# First installation detected...
# Checking NSS setup...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libmbim-glib4:amd64 (1.28.0-1~ubuntu20.04.2) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up iio-sensor-proxy (3.3-0ubuntu6) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5positioning5:amd64 (5.15.3+dfsg-3) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libmbim-proxy (1.28.0-1~ubuntu20.04.2) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up wpasupplicant (2:2.10-6ubuntu2.4) ...
# Created symlink /etc/systemd/system/dbus-fi.w1.wpa_supplicant1.service → /lib/systemd/system/wpa_supplicant.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/wpa_supplicant.service → /lib/systemd/system/wpa_supplicant.service.
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.5) ...
# Setting up libqt5qml5:amd64 (5.15.3+dfsg-1) ...
# Setting up libqt5webchannel5:amd64 (5.15.3-1) ...
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up avahi-daemon (0.8-5ubuntu5.4) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.Avahi.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/avahi-daemon.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/sockets.target.wants/avahi-daemon.socket → /lib/systemd/system/avahi-daemon.socket.
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libqt5qmlmodels5:amd64 (5.15.3+dfsg-1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqmi-glib5:amd64 (1.32.0-1ubuntu0.22.04.1) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5printsupport5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5quick5:amd64 (5.15.3+dfsg-1) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up libqmi-proxy (1.32.0-1ubuntu0.22.04.1) ...
# Setting up libqt5webkit5:amd64 (5.212.0~alpha4-15ubuntu1) ...
# Setting up modemmanager (1.20.0-1~ubuntu22.04.4) ...
# Created symlink /etc/systemd/system/dbus-org.freedesktop.ModemManager1.service → /lib/systemd/system/ModemManager.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/ModemManager.service → /lib/systemd/system/ModemManager.service.
# Setting up wkhtmltopdf (0.12.6-2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Setting up libgtk-3-bin (3.24.33-1ubuntu2.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up at-spi2-core (2.44.0-3) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3ubuntu0.6) ...
# Setting up geoclue-2.0 (2.5.7-3ubuntu3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...

# %%
print(df)
# Out:
#         Order_ID Customer_ID  Customer_Age Customer_Gender       City  \
# 0      ORD000001    CUST6948          19.0            Male        NaN
# 1      ORD000002    CUST6515           NaN          Female    Chennai
# 2      ORD000003    CUST1765           NaN            Male      Delhi
# 3      ORD000004    CUST2744           NaN            Male     Mumbai
# 4      ORD000005    CUST4389          57.0          Female    Chennai
# ...          ...         ...           ...             ...        ...
# 99995  ORD099996    CUST3722           NaN             NaN     Mumbai
# 99996  ORD099997    CUST6158           NaN            Male     Mumbai
# 99997  ORD099998    CUST2155           NaN             NaN      Delhi
# 99998  ORD099999    CUST3015           NaN          Female      Delhi
# 99999  ORD100000    CUST7959           NaN           Other  Hyderabad
#
#           Area Restaurant_ID Restaurant_Name Cuisine_Type  Order_Date  ...  \
# 0      Central        RES936   Restaurant_29      Chinese  10/20/2024  ...
# 1        North        RES689  Restaurant_419      Chinese   8/12/2024  ...
# 2          NaN        RES723  Restaurant_244      Arabian   12/8/2024  ...
# 3      Central        RES951  Restaurant_178      Chinese   10/8/2024  ...
# 4        South        RES419  Restaurant_262      Chinese    2/4/2024  ...
# ...        ...           ...             ...          ...         ...  ...
# 99995      NaN        RES295  Restaurant_500      Arabian   6/10/2024  ...
# 99996     East        RES157  Restaurant_458      Arabian   4/22/2024  ...
# 99997     East        RES287  Restaurant_273          NaN   2/23/2024  ...
# 99998    North        RES491  Restaurant_241          NaN  12/10/2024  ...
# 99999     East        RES680  Restaurant_237      Chinese         NaN  ...
#
#       Final_Amount  Payment_Mode  Order_Status  Cancellation_Reason  \
# 0              NaN           UPI     Delivered                  NaN
# 1           4849.0           COD     Delivered                  NaN
# 2            737.0        Wallet     Delivered                  NaN
# 3              NaN           UPI     Cancelled        Late Delivery
# 4            352.0          Card     Delivered                  NaN
# ...            ...           ...           ...                  ...
# 99995        132.0          Card     Delivered                  NaN
# 99996       1078.0           NaN     Delivered                  NaN
# 99997          NaN           COD     Cancelled                  NaN
# 99998          NaN           NaN     Delivered                  NaN
# 99999          NaN        Wallet     Cancelled                  NaN
#
#        Delivery_Partner_ID  Delivery_Rating Restaurant_Rating Order_Day  \
# 0                    DP563              5.0               4.4   Weekend
# 1                    DP369              5.0               4.7   Weekday
# 2                    DP580              4.0               4.9   Weekend
# 3                    DP155              2.0               3.4   Weekday
# 4                    DP728              2.0               4.4   Weekend
# ...                    ...              ...               ...       ...
# 99995                DP835              2.0               4.0   Weekday
# 99996                DP476              4.0               3.5   Weekday
# 99997                DP577              2.0               4.0   Weekday
# 99998                DP896              NaN               4.3   Weekday
# 99999                DP908              5.0               4.2   Weekday
#
#       Peak_Hour Profit_Margin
# 0          True          0.13
# 1          True          0.48
# 2          True          0.08
# 3           NaN          0.04
# 4         False          0.12
# ...         ...           ...
# 99995      True          0.17
# 99996     False         -0.15
# 99997      True          0.47
# 99998       NaN          0.44
# 99999     False          0.20
#
# [100000 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Order_ID             100000 non-null  object
#  1   Customer_ID          100000 non-null  object
#  2   Customer_Age         49907 non-null   float64
#  3   Customer_Gender      75144 non-null   object
#  4   City                 83274 non-null   object
#  5   Area                 83315 non-null   object
#  6   Restaurant_ID        100000 non-null  object
#  7   Restaurant_Name      100000 non-null  object
#  8   Cuisine_Type         83115 non-null   object
#  9   Order_Date           98986 non-null   object
#  10  Order_Time           98002 non-null   object
#  11  Delivery_Time_Min    66641 non-null   float64
#  12  Distance_km          66530 non-null   float64
#  13  Order_Value          66673 non-null   float64
#  14  Discount_Applied     83285 non-null   float64
#  15  Final_Amount         44303 non-null   float64
#  16  Payment_Mode         80089 non-null   object
#  17  Order_Status         100000 non-null  object
#  18  Cancellation_Reason  9031 non-null    object
#  19  Delivery_Partner_ID  100000 non-null  object
#  20  Delivery_Rating      83477 non-null   float64
#  21  Restaurant_Rating    100000 non-null  float64
#  22  Order_Day            100000 non-null  object
#  23  Peak_Hour            67038 non-null   object
#  24  Profit_Margin        100000 non-null  float64
# dtypes: float64(9), object(16)
# memory usage: 19.1+ MB

# %%
print(df.dtypes)
# Out:
# Order_ID                object
# Customer_ID             object
# Customer_Age           float64
# Customer_Gender         object
# City                    object
# Area                    object
# Restaurant_ID           object
# Restaurant_Name         object
# Cuisine_Type            object
# Order_Date              object
# Order_Time              object
# Delivery_Time_Min      float64
# Distance_km            float64
# Order_Value            float64
# Discount_Applied       float64
# Final_Amount           float64
# Payment_Mode            object
# Order_Status            object
# Cancellation_Reason     object
# Delivery_Partner_ID     object
# Delivery_Rating        float64
# Restaurant_Rating      float64
# Order_Day               object
# Peak_Hour               object
# Profit_Margin          float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Customer_ID                0
# Customer_Age           50093
# Customer_Gender        24856
# City                   16726
# Area                   16685
# Restaurant_ID              0
# Restaurant_Name            0
# Cuisine_Type           16885
# Order_Date              1014
# Order_Time              1998
# Delivery_Time_Min      33359
# Distance_km            33470
# Order_Value            33327
# Discount_Applied       16715
# Final_Amount           55697
# Payment_Mode           19911
# Order_Status               0
# Cancellation_Reason    90969
# Delivery_Partner_ID        0
# Delivery_Rating        16523
# Restaurant_Rating          0
# Order_Day                  0
# Peak_Hour              32962
# Profit_Margin              0
# dtype: int64

# %% [markdown]
# # **DATA CLEANING AND PREPROCESSING**

# %%
# Calculate percentage of nulls in each column
null_percent = df.isnull().mean() * 100
print(null_percent.sort_values(ascending=False))
# Out:
# Cancellation_Reason    90.969
# Final_Amount           55.697
# Customer_Age           50.093
# Distance_km            33.470
# Delivery_Time_Min      33.359
# Order_Value            33.327
# Peak_Hour              32.962
# Customer_Gender        24.856
# Payment_Mode           19.911
# Cuisine_Type           16.885
# City                   16.726
# Discount_Applied       16.715
# Area                   16.685
# Delivery_Rating        16.523
# Order_Time              1.998
# Order_Date              1.014
# Order_ID                0.000
# Restaurant_Name         0.000
# Restaurant_ID           0.000
# Customer_ID             0.000
# Order_Status            0.000
# Delivery_Partner_ID     0.000
# Restaurant_Rating       0.000
# Order_Day               0.000
# Profit_Margin           0.000
# dtype: float64

# %% [markdown]
# **Handling missing values using mean, median, or** **mode**

# %%
#Column 1:Order_ID,Column 2:Customer_ID,Column 7:Restaurant_ID,Column 8:Restaurant_Name,Column 18:Order_Status,Column 20:Delivery_Partner_ID,
#Column 22:Restaurant_Rating,Column 23:Order_Day,Column 25:Profit_Margin are cleaned data


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Step 1: Replace 0 with NaN
df['Customer_Age'] = df['Customer_Age'].replace(0, np.nan)

# Step 2: Fill using gender median
df['Customer_Age'] = df['Customer_Age'].fillna(
    df.groupby('Customer_Gender')['Customer_Age'].transform('median')
)

# Step 3: Fill remaining using overall median
df['Customer_Age'] = df['Customer_Age'].fillna(df['Customer_Age'].median())

# Step 4: Convert to int
df['Customer_Age'] = df['Customer_Age'].astype(int)

print("Remaining Missing:", df['Customer_Age'].isna().sum())
plt.hist(df['Customer_Age'])
print(df['Customer_Age'])
# Out:
# Remaining Missing: 0
# 0        19
# 1        39
# 2        39
# 3        39
# 4        57
#          ..
# 99995    39
# 99996    39
# 99997    39
# 99998    39
# 99999    39
# Name: Customer_Age, Length: 100000, dtype: int64

# %%
# Convert to integer where appropriate (after handling NaNs) fir Customer_age
int_column=['Customer_Age']
print(int_column)
for col in int_column:
  df[col]=df[col].fillna(0).astype(int)
df
# Out:
# ['Customer_Age']
#         Order_ID Customer_ID  Customer_Age Customer_Gender       City  \
# 0      ORD000001    CUST6948            19            Male        NaN
# 1      ORD000002    CUST6515            39          Female    Chennai
# 2      ORD000003    CUST1765            39            Male      Delhi
# 3      ORD000004    CUST2744            39            Male     Mumbai
# 4      ORD000005    CUST4389            57          Female    Chennai
# ...          ...         ...           ...             ...        ...
# 99995  ORD099996    CUST3722            39             NaN     Mumbai
# 99996  ORD099997    CUST6158            39            Male     Mumbai
# 99997  ORD099998    CUST2155            39             NaN      Delhi
# 99998  ORD099999    CUST3015            39          Female      Delhi
# 99999  ORD100000    CUST7959            39           Other  Hyderabad
#
#           Area Restaurant_ID Restaurant_Name Cuisine_Type  Order_Date  ...  \
# 0      Central        RES936   Restaurant_29      Chinese  10/20/2024  ...
# 1        North        RES689  Restaurant_419      Chinese   8/12/2024  ...
# 2          NaN        RES723  Restaurant_244      Arabian   12/8/2024  ...
# 3      Central        RES951  Restaurant_178      Chinese   10/8/2024  ...
# 4        South        RES419  Restaurant_262      Chinese    2/4/2024  ...
# ...        ...           ...             ...          ...         ...  ...
# 99995      NaN        RES295  Restaurant_500      Arabian   6/10/2024  ...
# 99996     East        RES157  Restaurant_458      Arabian   4/22/2024  ...
# 99997     East        RES287  Restaurant_273          NaN   2/23/2024  ...
# 99998    North        RES491  Restaurant_241          NaN  12/10/2024  ...
# 99999     East        RES680  Restaurant_237      Chinese         NaN  ...
#
#       Final_Amount  Payment_Mode  Order_Status  Cancellation_Reason  \
# 0              NaN           UPI     Delivered                  NaN
# 1           4849.0           COD     Delivered                  NaN
# 2            737.0        Wallet     Delivered                  NaN
# 3              NaN           UPI     Cancelled        Late Delivery
# 4            352.0          Card     Delivered                  NaN
# ...            ...           ...           ...                  ...
# 99995        132.0          Card     Delivered                  NaN
# 99996       1078.0           NaN     Delivered                  NaN
# 99997          NaN           COD     Cancelled                  NaN
# 99998          NaN           NaN     Delivered                  NaN
# 99999          NaN        Wallet     Cancelled                  NaN
#
#        Delivery_Partner_ID  Delivery_Rating Restaurant_Rating Order_Day  \
# 0                    DP563              5.0               4.4   Weekend
# 1                    DP369              5.0               4.7   Weekday
# 2                    DP580              4.0               4.9   Weekend
# 3                    DP155              2.0               3.4   Weekday
# 4                    DP728              2.0               4.4   Weekend
# ...                    ...              ...               ...       ...
# 99995                DP835              2.0               4.0   Weekday
# 99996                DP476              4.0               3.5   Weekday
# 99997                DP577              2.0               4.0   Weekday
# 99998                DP896              NaN               4.3   Weekday
# 99999                DP908              5.0               4.2   Weekday
#
#       Peak_Hour Profit_Margin
# 0          True          0.13
# 1          True          0.48
# 2          True          0.08
# 3           NaN          0.04
# 4         False          0.12
# ...         ...           ...
# 99995      True          0.17
# 99996     False         -0.15
# 99997      True          0.47
# 99998       NaN          0.44
# 99999     False          0.20
#
# [100000 rows x 25 columns]

# %%
# Convert categorical/object columns to 'category' for efficiency
cat_column=['Customer_Gender','City','Area','Cuisine_Type','Payment_Mode','Peak_Hour']
for col in cat_column:
  df[col]=df[col].astype('category')
  print(df.dtypes)
# Out:
# Order_ID                 object
# Customer_ID              object
# Customer_Age              int64
# Customer_Gender        category
# City                     object
# Area                     object
# Restaurant_ID            object
# Restaurant_Name          object
# Cuisine_Type             object
# Order_Date               object
# Order_Time               object
# Delivery_Time_Min       float64
# Distance_km             float64
# Order_Value             float64
# Discount_Applied        float64
# Final_Amount            float64
# Payment_Mode             object
# Order_Status             object
# Cancellation_Reason      object
# Delivery_Partner_ID      object
# Delivery_Rating         float64
# Restaurant_Rating       float64
# Order_Day                object
# Peak_Hour                object
# Profit_Margin           float64
# dtype: object
# Order_ID                 object
# Customer_ID              object
# Customer_Age              int64
# Customer_Gender        category
# City                   category
# Area                     object
# Restaurant_ID            object
# Restaurant_Name          object
# Cuisine_Type             object
# Order_Date               object
# Order_Time               object
# Delivery_Time_Min       float64
# Distance_km             float64
# Order_Value             float64
# Discount_Applied        float64
# Final_Amount            float64
# Payment_Mode             object
# Order_Status             object
# Cancellation_Reason      object
# Delivery_Partner_ID      object
# Delivery_Rating         float64
# Restaurant_Rating       float64
# Order_Day                object
# Peak_Hour                object
# Profit_Margin           float64
# dtype: object
# Order_ID                 object
# Customer_ID              object
# Customer_Age              int64
# Customer_Gender        category
# City                   category
# Area                   category
# Restaurant_ID            object
# Restaurant_Name          object
# Cuisine_Type             object
# Order_Date               object
# Order_Time               object
# Delivery_Time_Min       float64
# Distance_km             float64
# Order_Value             float64
# Discount_Applied        float64
# Final_Amount            float64
# Payment_Mode             object
# Order_Status             object
# Cancellation_Reason      object
# Delivery_Partner_ID      object
# Delivery_Rating         float64
# Restaurant_Rating       float64
# Order_Day                object
# Peak_Hour                object
# Profit_Margin           float64
# dtype: object
# Order_ID                 object
# Customer_ID              object
# Customer_Age              int64
# Customer_Gender        category
# City                   category
# Area                   category
# Restaurant_ID            object
# Restaurant_Name          object
# Cuisine_Type           category
# Order_Date               object
# Order_Time               object
# Delivery_Time_Min       float64
# Distance_km             float64
# Order_Value             float64
# Discount_Applied        float64
# Final_Amount            float64
# Payment_Mode             object
# Order_Status             object
# Cancellation_Reason      object
# Delivery_Partner_ID      object
# Delivery_Rating         float64
# Restaurant_Rating       float64
# Order_Day                object
# Peak_Hour                object
# Profit_Margin           float64
# dtype: object
# Order_ID                 object
# Customer_ID              object
# Customer_Age              int64
# Customer_Gender        category
# City                   category
# Area                   category
# Restaurant_ID            object
# Restaurant_Name          object
# Cuisine_Type           category
# Order_Date               object
# Order_Time               object
# Delivery_Time_Min       float64
# Distance_km             float64
# Order_Value             float64
# Discount_Applied        float64
# Final_Amount            float64
# Payment_Mode           category
# Order_Status             object
# Cancellation_Reason      object
# Delivery_Partner_ID      object
# Delivery_Rating         float64
# Restaurant_Rating       float64
# Order_Day                object
# Peak_Hour                object
# Profit_Margin           float64
# dtype: object
# Order_ID                 object
# Customer_ID              object
# Customer_Age              int64
# Customer_Gender        category
# City                   category
# Area                   category
# Restaurant_ID            object
# Restaurant_Name          object
# Cuisine_Type           category
# Order_Date               object
# Order_Time               object
# Delivery_Time_Min       float64
# Distance_km             float64
# Order_Value             float64
# Discount_Applied        float64
# Final_Amount            float64
# Payment_Mode           category
# Order_Status             object
# Cancellation_Reason      object
# Delivery_Partner_ID      object
# Delivery_Rating         float64
# Restaurant_Rating       float64
# Order_Day                object
# Peak_Hour              category
# Profit_Margin           float64
# dtype: object

# %%
# Filling the Null values for Customer_Gender Column with the most frequent value (mode)
df['Customer_Gender'] = df['Customer_Gender'].fillna(df['Customer_Gender'].mode()[0])
print(df['Customer_Gender'])
# Out:
# 0          Male
# 1        Female
# 2          Male
# 3          Male
# 4        Female
#           ...
# 99995     Other
# 99996      Male
# 99997     Other
# 99998    Female
# 99999     Other
# Name: Customer_Gender, Length: 100000, dtype: category
# Categories (3, object): ['Female', 'Male', 'Other']

# %%
#Fill city values with mode

#Step1:Clean the City Column Properly
df['City'] = df['City'].astype(str).str.strip().str.title()

#Step2:Convert Fake Missing Values to Real NaN
import numpy as np

df['City'] = df['City'].replace(['Nan', 'None', 'Null', ''], np.nan)

#Step3:Now Apply Mode
df['City'] = df['City'].fillna(df['City'].mode().iloc[0])

#Step4:Check results
print(df['City'].value_counts())

print(df['City'])
# Out:
# City
# Hyderabad    33610
# Bangalore    16732
# Delhi        16695
# Mumbai       16493
# Chennai      16470
# Name: count, dtype: int64
# 0        Hyderabad
# 1          Chennai
# 2            Delhi
# 3           Mumbai
# 4          Chennai
#            ...
# 99995       Mumbai
# 99996       Mumbai
# 99997        Delhi
# 99998        Delhi
# 99999    Hyderabad
# Name: City, Length: 100000, dtype: object

# %%
#Fill Area values with mode
df['Area']= df['Area'].fillna(df['Area'].mode()[0])
print(df['Area'])
# Out:
# 0        Central
# 1          North
# 2          South
# 3        Central
# 4          South
#           ...
# 99995      South
# 99996       East
# 99997       East
# 99998      North
# 99999       East
# Name: Area, Length: 100000, dtype: category
# Categories (5, object): ['Central', 'East', 'North', 'South', 'West']

# %%
#Fill Cuisine_Type with mode
df['Cuisine_Type']=df['Cuisine_Type'].fillna(df['Cuisine_Type'].mode()[0])
print(df['Cuisine_Type'])
# Out:
# 0        Chinese
# 1        Chinese
# 2        Arabian
# 3        Chinese
# 4        Chinese
#           ...
# 99995    Arabian
# 99996    Arabian
# 99997     Indian
# 99998     Indian
# 99999    Chinese
# Name: Cuisine_Type, Length: 100000, dtype: category
# Categories (5, object): ['Arabian', 'Chinese', 'Indian', 'Italian', 'Mexican']

# %%
#convert Order_Date to datetime
df['Order_Date']=pd.to_datetime(df['Order_Date'],errors='coerce')
print(df['Order_Date'])

#Fill with Most Frequent Date for missing dates
df['Order_Date'] = df['Order_Date'].fillna(df['Order_Date'].mode()[0])

#To check missing values
print(df['Order_Date'].isna().sum())
# Out:
# 0       2024-10-20
# 1       2024-08-12
# 2       2024-12-08
# 3       2024-10-08
# 4       2024-02-04
#            ...
# 99995   2024-06-10
# 99996   2024-04-22
# 99997   2024-02-23
# 99998   2024-12-10
# 99999          NaT
# Name: Order_Date, Length: 100000, dtype: datetime64[ns]
# 0

# %%
#handling missing values for Delivery_Rating by using fill

# Convert rating column to numeric
df['Delivery_Rating'] = pd.to_numeric(df['Delivery_Rating'], errors='coerce')

# Check missing values
print("Missing before cleaning:", df['Delivery_Rating'].isnull().sum())

# Fill missing values with median rating
df['Delivery_Rating'] = df['Delivery_Rating'].fillna(df['Delivery_Rating'].median())

# Check again
print("Missing after cleaning:", df['Delivery_Rating'].isnull().sum())

# Convert to integer (optional)
df['Delivery_Rating'] = df['Delivery_Rating'].astype(int)

print(df['Delivery_Rating'].head())
# Out:
# Missing before cleaning: 0
# Missing after cleaning: 0
# 0    5
# 1    5
# 2    4
# 3    2
# 4    2
# Name: Delivery_Rating, dtype: int64

# %%
#Fill null values for Delivery_Time_Min by using imputation Techniques
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# Ensure numeric
df['Delivery_Time_Min'] = pd.to_numeric(df['Delivery_Time_Min'], errors='coerce')

# Impute
imputer = SimpleImputer(strategy='mean')
df['Delivery_Time_Min'] = imputer.fit_transform(df[['Delivery_Time_Min']]).ravel()

# Scale
scaler = StandardScaler()
df['Delivery_Time_Min'] = scaler.fit_transform(df[['Delivery_Time_Min']]).ravel()

print(df['Delivery_Time_Min'])
# Out:
# 0        0.806973
# 1       -1.452258
# 2        1.077540
# 3        0.211727
# 4       -1.032879
#            ...
# 99993    0.001712
# 99995    0.001712
# 99996   -1.100521
# 99997   -1.262861
# 99999   -0.802898
# Name: Delivery_Time_Min, Length: 68366, dtype: float64

# %%
# Filling missing values for Distance_km
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# Ensure numeric
df['Distance_km'] = pd.to_numeric(df['Distance_km'], errors='coerce')

# Median imputation
imputer = SimpleImputer(strategy='median')
df['Distance_km'] = imputer.fit_transform(df[['Distance_km']]).ravel()

# Scale
scaler = StandardScaler()
df['Distance_km'] = scaler.fit_transform(df[['Distance_km']]).ravel()


print("Missing values after imputation:",
df['Distance_km'].isna().sum())

print(df['Distance_km'])
df.head()
# Out:
# Missing values after imputation: 0
# 0        0.136949
# 1        1.449602
# 2       -0.414842
# 3        0.130266
# 4       -0.450165
#            ...
# 99993   -0.414842
# 99995   -0.414842
# 99996   -0.414842
# 99997    0.406162
# 99999   -0.414842
# Name: Distance_km, Length: 68366, dtype: float64
#     Order_ID Customer_ID  Customer_Age Customer_Gender       City     Area  \
# 0  ORD000001    CUST6948            19            Male  Hyderabad  Central
# 1  ORD000002    CUST6515            39          Female    Chennai    North
# 2  ORD000003    CUST1765            39            Male      Delhi    South
# 3  ORD000004    CUST2744            39            Male     Mumbai  Central
# 4  ORD000005    CUST4389            57          Female    Chennai    South
#
#   Restaurant_ID Restaurant_Name Cuisine_Type Order_Date  ... Payment_Mode  \
# 0        RES936   Restaurant_29      Chinese 2024-10-20  ...          Upi
# 1        RES689  Restaurant_419      Chinese 2024-08-12  ...          Cod
# 2        RES723  Restaurant_244      Arabian 2024-12-08  ...       Wallet
# 3        RES951  Restaurant_178      Chinese 2024-10-08  ...          Upi
# 4        RES419  Restaurant_262      Chinese 2024-02-04  ...         Card
#
#    Order_Status  Cancellation_Reason  Delivery_Partner_ID  Delivery_Rating  \
# 0     Delivered                  Nan                DP563                5
# 1     Delivered                  Nan                DP369                5
# 2     Delivered                  Nan                DP580                4
# 3     Cancelled        Late Delivery                DP155                2
# 4     Delivered                  Nan                DP728                2
#
#    Restaurant_Rating Order_Day Peak_Hour Profit_Margin Delivery_Rating_Missing
# 0                4.4   Weekend      True          0.13                       0
# 1                4.7   Weekday      True          0.48                       0
# 2                4.9   Weekend      True          0.08                       0
# 3                3.4   Weekday      True          0.04                       0
# 4                4.4   Weekend     False          0.12                       0
#
# [5 rows x 26 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
df[['Distance_km','Order_Value']] = imputer.fit_transform(df[['Distance_km','Order_Value']])

print(df[['Distance_km','Order_Value']])
# Out:
#        Distance_km  Order_Value
# 0         0.136949       1197.0
# 1         1.449602       4869.0
# 2        -0.414842        757.0
# 3         0.130266       1197.0
# 4        -0.450165        372.0
# ...            ...          ...
# 99993    -0.414842       4193.0
# 99995    -0.414842        232.0
# 99996    -0.414842       1098.0
# 99997     0.406162       1197.0
# 99999    -0.414842       2909.0
#
# [68366 rows x 2 columns]

# %%
#Filling the Missing values of Discount_Applied

# Replace missing with 0
df['Discount_Applied'] = df['Discount_Applied'].fillna(0)

print(df['Discount_Applied'])
# Out:
# 0          0.0
# 1         20.0
# 2         20.0
# 3          0.0
# 4         20.0
#          ...
# 99993     20.0
# 99995    100.0
# 99996     20.0
# 99997     20.0
# 99999      0.0
# Name: Discount_Applied, Length: 68366, dtype: float64

# %%
#Filling the missing values for Final_Amount

df['Final_Amount'].isna().sum()
df['Discount_Applied'].unique()
df['Discount_Applied'] = df['Discount_Applied'].fillna(0)
print(df['Discount_Applied'])
df['Final_Amount'] = df['Order_Value'] - df['Discount_Applied']
print(df['Final_Amount'])
# Out:
# 0          0.0
# 1         20.0
# 2         20.0
# 3          0.0
# 4         20.0
#          ...
# 99993     20.0
# 99995    100.0
# 99996     20.0
# 99997     20.0
# 99999      0.0
# Name: Discount_Applied, Length: 68366, dtype: float64
# 0        1197.0
# 1        4849.0
# 2         737.0
# 3        1197.0
# 4         352.0
#           ...
# 99993    4173.0
# 99995     132.0
# 99996    1078.0
# 99997    1177.0
# 99999    2909.0
# Name: Final_Amount, Length: 68366, dtype: float64

# %%
#Handling the missing values for Payment_Mode
df['Payment_Mode'].unique()
df['Payment_Mode']=df['Payment_Mode'].fillna(df['Payment_Mode'].mode()[0])
print(df['Payment_Mode'])
# Out:
# 0           Upi
# 1           Cod
# 2        Wallet
# 3           Upi
# 4          Card
#           ...
# 99993      Card
# 99995      Card
# 99996      Card
# 99997       Cod
# 99999    Wallet
# Name: Payment_Mode, Length: 68366, dtype: object

# %%
#Handle the missing values for Cancellation_Reason using mode
df['Cancellation_Reason'].unique()
df['Cancellation_Reason'].fillna(df['Cancellation_Reason'].mode()[0])
print(df['Cancellation_Reason'])
# Out:
# 0                  Nan
# 1                  Nan
# 2                  Nan
# 3        Late Delivery
# 4                  Nan
#              ...
# 99993              Nan
# 99995              Nan
# 99996              Nan
# 99997              Nan
# 99999              Nan
# Name: Cancellation_Reason, Length: 68366, dtype: object

# %%
#Revenue Per City
df.groupby('City')['Final_Amount'].sum().reset_index()
# Out:
#         City  Final_Amount
# 0  Bangalore    19664934.0
# 1    Chennai    19372832.0
# 2      Delhi    19383649.0
# 3  Hyderabad    39095504.0
# 4     Mumbai    19313701.0

# %%
#Average Delivery Time Per City
df.groupby('City',observed=True)['Delivery_Time_Min'].mean().reset_index()
# Out:
#         City  Delivery_Time_Min
# 0  Bangalore          -0.010779
# 1    Chennai          -0.006059
# 2      Delhi           0.003777
# 3  Hyderabad           0.001689
# 4     Mumbai           0.009773

# %%
#Cancellation Count by City

df[df['Order_Status'] == 'Cancelled'].groupby('City', observed=True).size()\
.reset_index(name='Cancellation_Count')
# Out:
#         City  Cancellation_Count
# 0  Bangalore                1726
# 1    Chennai                1723
# 2      Delhi                1729
# 3  Hyderabad                3446
# 4     Mumbai                1713

# %%
#Average Rating Per Restaurant
df.groupby('Restaurant_Name')['Restaurant_Rating'].mean().reset_index()
# Out:
#     Restaurant_Name  Restaurant_Rating
# 0      Restaurant_1           4.142857
# 1     Restaurant_10           4.068841
# 2    Restaurant_100           4.074419
# 3    Restaurant_101           4.114414
# 4    Restaurant_102           3.988372
# ..              ...                ...
# 495   Restaurant_95           4.045000
# 496   Restaurant_96           4.030000
# 497   Restaurant_97           3.983459
# 498   Restaurant_98           4.029752
# 499   Restaurant_99           4.017213
#
# [500 rows x 2 columns]

# %%
#Profit by Cuisine Type

df.groupby('Cuisine_Type', observed=True)['Profit_Margin'].sum().reset_index()
# Out:
#   Cuisine_Type  Profit_Margin
# 0      Arabian        2046.64
# 1      Chinese        2050.24
# 2       Indian        4111.32
# 3      Italian        1991.02
# 4      Mexican        2046.09

# %%
#Filling null values for Order_Time
import pandas as pd
import numpy as np

# Step 1: Convert to datetime
df['Order_Time'] = pd.to_datetime(df['Order_Time'], errors='coerce')

# Step 2: Fill missing using most frequent time per Restaurant
df['Order_Time'] = df['Order_Time'].fillna(
    df.groupby('Restaurant_ID')['Order_Time']
      .transform(lambda x: x.mode()[0] if not x.mode().empty else pd.NaT)
)

# Step 3: Fill remaining using overall most frequent time
df['Order_Time'] = df['Order_Time'].fillna(df['Order_Time'].mode()[0])
print(df['Order_Time'])

# Step 4: Check
print("Remaining Missing:", df['Order_Time'].isna().sum())
# Out:
# 0       2026-03-04
# 1       2026-03-04
# 2       2026-03-04
# 3       2026-03-04
# 4       2026-03-04
#            ...
# 99993   2026-03-04
# 99995   2026-03-04
# 99996   2026-03-04
# 99997   2026-03-04
# 99999   2026-03-04
# Name: Order_Time, Length: 68366, dtype: datetime64[ns]
# Remaining Missing: 0

# %%
#handling missing values for Delivery_Rating by using fill

df['Delivery_Rating_Missing'] = df['Delivery_Rating'].isna().astype(int)
df['Delivery_Rating'] = df['Delivery_Rating'].fillna(0)
print(df['Delivery_Rating'])
# Out:
# 0        5
# 1        5
# 2        4
# 3        2
# 4        2
#         ..
# 99993    3
# 99995    2
# 99996    4
# 99997    2
# 99999    5
# Name: Delivery_Rating, Length: 68366, dtype: int64

# %%
#Filling Nan for Peak_Hour


import numpy as np

# Step 1: Convert empty to NaN (if needed)
df['Peak_Hour'] = df['Peak_Hour'].replace('', np.nan)

# Step 2: Fill missing using most frequent value per Order_Day
df['Peak_Hour'] = df['Peak_Hour'].fillna(
    df.groupby('Order_Day')['Peak_Hour']
      .transform(lambda x: x.mode()[0] if not x.mode().empty else False)
)

# Step 3: If still any missing, fill with False
df['Peak_Hour'] = df['Peak_Hour'].fillna(False)

# Step 4: Convert to boolean
df['Peak_Hour'] = df['Peak_Hour'].astype(bool)
print(df['Peak_Hour'])


print("Remaining Missing:", df['Peak_Hour'].isna().sum())
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 99993    False
# 99995     True
# 99996    False
# 99997     True
# 99999    False
# Name: Peak_Hour, Length: 68366, dtype: bool
# Remaining Missing: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68366 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Order_ID                 68366 non-null  object
#  1   Customer_ID              68366 non-null  object
#  2   Customer_Age             68366 non-null  int64
#  3   Customer_Gender          68366 non-null  category
#  4   City                     68366 non-null  object
#  5   Area                     68366 non-null  object
#  6   Restaurant_ID            68366 non-null  object
#  7   Restaurant_Name          68366 non-null  object
#  8   Cuisine_Type             68366 non-null  object
#  9   Order_Date               68366 non-null  datetime64[ns]
#  10  Order_Time               68366 non-null  datetime64[ns]
#  11  Delivery_Time_Min        68366 non-null  float64
#  12  Distance_km              68366 non-null  float64
#  13  Order_Value              68366 non-null  float64
#  14  Discount_Applied         68366 non-null  float64
#  15  Final_Amount             68366 non-null  float64
#  16  Payment_Mode             68366 non-null  object
#  17  Order_Status             68366 non-null  object
#  18  Cancellation_Reason      68366 non-null  object
#  19  Delivery_Partner_ID      68366 non-null  object
#  20  Delivery_Rating          68366 non-null  int64
#  21  Restaurant_Rating        68366 non-null  float64
#  22  Order_Day                68366 non-null  object
#  23  Peak_Hour                68366 non-null  bool
#  24  Profit_Margin            68366 non-null  float64
#  25  Delivery_Rating_Missing  68366 non-null  int64
# dtypes: bool(1), category(1), datetime64[ns](2), float64(7), int64(3), object(12)
# memory usage: 13.2+ MB

# %% [markdown]
# **Removing or capping outliers (delivery time, order value)**

# %%
df_temp=df.copy()
# Select only numeric columns
numeric_cols = df_temp.select_dtypes(include=['int64', 'float64']).columns

# Loop through each numeric column and detect outliers using IQR
for col in numeric_cols:
    Q1 = df_temp[col].quantile(0.25)   # First quartile (25%)
    Q3 = df_temp[col].quantile(0.75)   # Third quartile (75%)
    IQR = Q3 - Q1                      # Interquartile Range

    lower_bound = Q1 - 1.5 * IQR       # Lower limit for outliers
    upper_bound = Q3 + 1.5 * IQR       # Upper limit for outliers

    outliers = df_temp[(df_temp[col] < lower_bound) | (df_temp[col] > upper_bound)]

    print(f"📌 Column: {col} — Found {len(outliers)} outliers")
# Out:
# 📌 Column: Customer_Age — Found 33186 outliers
# 📌 Column: Delivery_Time_Min — Found 0 outliers
# 📌 Column: Distance_km — Found 0 outliers
# 📌 Column: Order_Value — Found 0 outliers
# 📌 Column: Discount_Applied — Found 11368 outliers
# 📌 Column: Final_Amount — Found 0 outliers
# 📌 Column: Delivery_Rating — Found 0 outliers
# 📌 Column: Restaurant_Rating — Found 0 outliers
# 📌 Column: Profit_Margin — Found 0 outliers
# 📌 Column: Delivery_Rating_Missing — Found 0 outliers

# %%
#Capping Customer_Age values
df['Customer_Age'] = np.clip(df['Customer_Age'], 18, 60)
print(df['Customer_Age'])
print(df['Customer_Age'].describe())
# Out:
# 0        19
# 1        39
# 2        39
# 3        39
# 4        57
#          ..
# 99993    28
# 99995    39
# 99996    39
# 99997    39
# 99999    39
# Name: Customer_Age, Length: 68366, dtype: int64
# count    68366.000000
# mean        38.973905
# std          8.726322
# min         18.000000
# 25%         39.000000
# 50%         39.000000
# 75%         39.000000
# max         60.000000
# Name: Customer_Age, dtype: float64

# %%
print(df['Delivery_Time_Min'].describe())
#This is z-score normalized data
#1.44 standard deviations below mean
# Out:
# count    6.836600e+04
# mean     2.902306e-17
# std      1.000007e+00
# min     -1.452258e+00
# 25%     -9.381810e-01
# 50%      1.712048e-03
# 75%      4.958217e-01
# max      2.335674e+00
# Name: Delivery_Time_Min, dtype: float64

# %%
import pandas as pd
from scipy.stats import skew

# Step 1: Load your cleaned dataset (null values already handled)
# Example: df is your working DataFrame

# Step 2: Check original skewness
original_skew = df['Customer_Age'].skew()
print(f"📊 Original Skewness of Customer_Age: {original_skew:.2f}")

# Step 3: Handle outliers using IQR (as an example)
Q1 = df['Customer_Age'].quantile(0.25)
Q3 = df['Customer_Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 4: Remove outliers (or you can cap instead)
df_outlier_removed = df[(df['Customer_Age'] >= lower_bound) & (df['Customer_Age'] <= upper_bound)]

# Step 5: Check skewness after outlier removal
new_skew = df_outlier_removed['Customer_Age'].skew()
print(f"✅ Skewness of Customer_Age after outlier removal: {new_skew:.2f}")
# Out:
# 📊 Original Skewness of Customer_Age: -0.01
# ✅ Skewness of Customer_Age after outlier removal: 0.00

# %%
import pandas as pd

# Assuming df is your cleaned DataFrame (nulls handled)

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['int64', 'float64'])

# Calculate skewness for each column
skewness_values = numeric_cols.skew()

# Display skewness nicely
print("📈 Skewness of Numeric Columns:\n")
for col, val in skewness_values.items():
    print(f"🔹 {col}: {val:.2f}")
# Out:
# 📈 Skewness of Numeric Columns:
#
# 🔹 Customer_Age: -0.01
# 🔹 Delivery_Time_Min: 0.50
# 🔹 Distance_km: 0.99
# 🔹 Order_Value: 0.98
# 🔹 Discount_Applied: 1.40
# 🔹 Final_Amount: 0.97
# 🔹 Delivery_Rating: 0.01
# 🔹 Restaurant_Rating: -0.01
# 🔹 Profit_Margin: 0.39
# 🔹 Delivery_Rating_Missing: 0.00

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# Step 1: Copy your original dataframe
df_temp = df.copy()

# Step 2: Encode categorical columns with NaNs using LabelEncoder safely
label_encoders = {}
for col in df_temp.select_dtypes(include='object').columns:
    df_temp[col] = df_temp[col].astype(str)  # for LabelEncoder to work
    le = LabelEncoder()
    df_temp[col] = le.fit_transform(df_temp[col])
    label_encoders[col] = le  # Save for inverse if needed

# Step 3: Use SimpleImputer for Numeric columns
num_imputer = SimpleImputer(strategy='median')
num_cols = df_temp.select_dtypes(include=['int64', 'float64']).columns
df_temp[num_cols] = num_imputer.fit_transform(df_temp[num_cols])
print(df_temp[num_cols])
# Out:
#        Order_ID  Customer_ID  Customer_Age  City  Area  Restaurant_ID  \
# 0           0.0       5945.0          19.0   3.0   0.0          836.0
# 1           1.0       5512.0          39.0   1.0   2.0          589.0
# 2           2.0        765.0          39.0   2.0   3.0          623.0
# 3           3.0       1743.0          39.0   4.0   0.0          851.0
# 4           4.0       3387.0          57.0   1.0   3.0          319.0
# ...         ...          ...           ...   ...   ...            ...
# 99993   68361.0       7331.0          28.0   2.0   1.0          818.0
# 99995   68362.0       2720.0          39.0   4.0   3.0          195.0
# 99996   68363.0       5155.0          39.0   4.0   1.0           57.0
# 99997   68364.0       1155.0          39.0   2.0   1.0          187.0
# 99999   68365.0       6956.0          39.0   3.0   1.0          580.0
#
#        Restaurant_Name  Cuisine_Type  Delivery_Time_Min  Distance_km  ...  \
# 0                211.0           1.0           0.806973     0.136949  ...
# 1                355.0           1.0          -1.452258     1.449602  ...
# 2                161.0           0.0           1.077540    -0.414842  ...
# 3                 87.0           1.0           0.211727     0.130266  ...
# 4                181.0           1.0          -1.032879    -0.450165  ...
# ...                ...           ...                ...          ...  ...
# 99993            118.0           2.0           0.001712    -0.414842  ...
# 99995            446.0           0.0           0.001712    -0.414842  ...
# 99996            398.0           0.0          -1.100521    -0.414842  ...
# 99997            193.0           2.0          -1.262861     0.406162  ...
# 99999            153.0           1.0          -0.802898    -0.414842  ...
#
#        Final_Amount  Payment_Mode  Order_Status  Cancellation_Reason  \
# 0            1197.0           2.0           1.0                  2.0
# 1            4849.0           1.0           1.0                  2.0
# 2             737.0           3.0           1.0                  2.0
# 3            1197.0           2.0           0.0                  1.0
# 4             352.0           0.0           1.0                  2.0
# ...             ...           ...           ...                  ...
# 99993        4173.0           0.0           1.0                  2.0
# 99995         132.0           0.0           1.0                  2.0
# 99996        1078.0           0.0           1.0                  2.0
# 99997        1177.0           1.0           0.0                  2.0
# 99999        2909.0           3.0           0.0                  2.0
#
#        Delivery_Partner_ID  Delivery_Rating  Restaurant_Rating  Order_Day  \
# 0                    463.0              5.0                4.4        1.0
# 1                    269.0              5.0                4.7        0.0
# 2                    480.0              4.0                4.9        1.0
# 3                     55.0              2.0                3.4        0.0
# 4                    628.0              2.0                4.4        1.0
# ...                    ...              ...                ...        ...
# 99993                419.0              3.0                3.7        0.0
# 99995                735.0              2.0                4.0        0.0
# 99996                376.0              4.0                3.5        0.0
# 99997                477.0              2.0                4.0        0.0
# 99999                808.0              5.0                4.2        0.0
#
#        Profit_Margin  Delivery_Rating_Missing
# 0               0.13                      0.0
# 1               0.48                      0.0
# 2               0.08                      0.0
# 3               0.04                      0.0
# 4               0.12                      0.0
# ...              ...                      ...
# 99993           0.42                      0.0
# 99995           0.17                      0.0
# 99996           0.00                      0.0
# 99997           0.47                      0.0
# 99999           0.20                      0.0
#
# [68366 rows x 22 columns]

# %%
#Delivery_Rating and Restaurant_Rating
#Here we don't need IQR
#These usually range from 1–5
df = df[(df['Delivery_Rating'] >= 1) & (df['Delivery_Rating'] <= 5)]
df = df[(df['Restaurant_Rating'] >= 1) & (df['Restaurant_Rating'] <= 5)]  #That’s better than statistical outlier detection.

df[['Restaurant_Rating', 'Delivery_Rating']].describe()
# Out:
#        Restaurant_Rating  Delivery_Rating
# count       68366.000000     68366.000000
# mean            4.026984         2.991077
# std             0.591958         1.413647
# min             3.000000         1.000000
# 25%             3.500000         2.000000
# 50%             4.000000         3.000000
# 75%             4.500000         4.000000
# max             5.000000         5.000000

# %%
# To see unique values
df['Restaurant_Rating'].unique()
df['Delivery_Rating'].unique() #This shows all rating values present
# Out:
# array([5, 4, 2, 3, 1])

# %%
#To See Rating Distribution (Counts)
df['Restaurant_Rating'].value_counts().sort_index()
df['Delivery_Rating'].value_counts().sort_index()
# Out:
# Delivery_Rating
# 1    13741
# 2    13896
# 3    13460
# 4    13770
# 5    13499
# Name: count, dtype: int64

# %%
#Visual Output (Boxplot) for Restaurant_Rating and Delivery_Rating

import matplotlib.pyplot as plt

plt.figure()
df.boxplot(column='Restaurant_Rating')
plt.show()

plt.figure()
df.boxplot(column='Delivery_Rating')
plt.show()

# %%
#Group By City (Business Insight) for Restaurant rating
df.groupby('City', observed=True)['Restaurant_Rating'].mean().reset_index()
# Out:
#         City  Restaurant_Rating
# 0  Bangalore           4.027200
# 1    Chennai           4.030621
# 2      Delhi           4.023940
# 3  Hyderabad           4.029906
# 4     Mumbai           4.020239

# %%
#Group By City (Business Insight) for Delivery rating
df.groupby('City', observed=True)['Delivery_Rating'].mean().reset_index()
# Out:
#         City  Delivery_Rating
# 0  Bangalore         2.990913
# 1    Chennai         2.974998
# 2      Delhi         2.988742
# 3  Hyderabad         3.003398
# 4     Mumbai         2.984663

# %%
#Correcting invalid values (ratings > 5, negative profit margin)

# Fix ratings
df['Restaurant_Rating'] = df['Restaurant_Rating'].clip(lower=1, upper=5)
df['Delivery_Rating'] = df['Delivery_Rating'].clip(lower=1, upper=5)

# Fix negative profit
df['Profit_Margin'] = df['Profit_Margin'].clip(lower=0)
df[df['Profit_Margin'] < 0] # Check Negative Profit
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Customer_Age, Customer_Gender, City, Area, Restaurant_ID, Restaurant_Name, Cuisine_Type, Order_Date, Order_Time, Delivery_Time_Min, Distance_km, Order_Value, Discount_Applied, Final_Amount, Payment_Mode, Order_Status, Cancellation_Reason, Delivery_Partner_ID, Delivery_Rating, Restaurant_Rating, Order_Day, Peak_Hour, Profit_Margin, Delivery_Rating_Missing, Day_Type, Order_Hour, Peak_Indicator, Profit_Margin_Percentage]
# Index: []
#
# [0 rows x 30 columns]

# %%
df.shape
# Out:
# (68366, 26)

# %%
#To check total profit
df['Profit_Margin'].sum()
# Out:
# np.float64(12245.31)

# %%
#Standarizing cateogorical values
cat_cols = [
    'City',
    'Area',
    'Cuisine_Type',
    'Restaurant_Name',
    'Order_Status',
    'Cancellation_Reason',
    'Payment_Mode',
    'Order_Day'
]

for col in cat_cols:
    df[col] = df[col].astype(str).str.strip().str.title()

df[['City', 'Area', 'Cuisine_Type',
    'Restaurant_Name', 'Order_Status',
    'Cancellation_Reason', 'Payment_Mode']].head()
# Out:
#         City     Area Cuisine_Type Restaurant_Name Order_Status  \
# 0  Hyderabad  Central      Chinese   Restaurant_29    Delivered
# 1    Chennai    North      Chinese  Restaurant_419    Delivered
# 2      Delhi    South      Arabian  Restaurant_244    Delivered
# 3     Mumbai  Central      Chinese  Restaurant_178    Cancelled
# 4    Chennai    South      Chinese  Restaurant_262    Delivered
#
#   Cancellation_Reason Payment_Mode
# 0                 Nan          Upi
# 1                 Nan          Cod
# 2                 Nan       Wallet
# 3       Late Delivery          Upi
# 4                 Nan         Card

# %%
#This shows all different category variations
cat_cols = [
    'City', 'Area', 'Cuisine_Type',
    'Restaurant_Name', 'Order_Status',
    'Cancellation_Reason', 'Payment_Mode'
]

for col in cat_cols:
    print(f"\n📌 Column: {col}")
    print(df[col].unique())
# Out:
# 📌 Column: City
# ['Hyderabad' 'Chennai' 'Delhi' 'Mumbai' 'Bangalore']
#
# 📌 Column: Area
# ['Central' 'North' 'South' 'East' 'West']
#
# 📌 Column: Cuisine_Type
# ['Chinese' 'Arabian' 'Mexican' 'Italian' 'Indian']
#
# 📌 Column: Restaurant_Name
# ['Restaurant_29' 'Restaurant_419' 'Restaurant_244' 'Restaurant_178'
#  'Restaurant_262' 'Restaurant_153' 'Restaurant_302' 'Restaurant_41'
#  'Restaurant_155' 'Restaurant_368' 'Restaurant_237' 'Restaurant_43'
#  'Restaurant_117' 'Restaurant_455' 'Restaurant_258' 'Restaurant_51'
#  'Restaurant_449' 'Restaurant_293' 'Restaurant_374' 'Restaurant_47'
#  'Restaurant_313' 'Restaurant_25' 'Restaurant_269' 'Restaurant_497'
#  'Restaurant_438' 'Restaurant_15' 'Restaurant_342' 'Restaurant_346'
#  'Restaurant_248' 'Restaurant_215' 'Restaurant_276' 'Restaurant_103'
#  'Restaurant_387' 'Restaurant_2' 'Restaurant_378' 'Restaurant_450'
#  'Restaurant_127' 'Restaurant_161' 'Restaurant_40' 'Restaurant_219'
#  'Restaurant_471' 'Restaurant_397' 'Restaurant_413' 'Restaurant_454'
#  'Restaurant_85' 'Restaurant_56' 'Restaurant_289' 'Restaurant_428'
#  'Restaurant_233' 'Restaurant_131' 'Restaurant_139' 'Restaurant_144'
#  'Restaurant_492' 'Restaurant_253' 'Restaurant_447' 'Restaurant_475'
#  'Restaurant_487' 'Restaurant_5' 'Restaurant_494' 'Restaurant_138'
#  'Restaurant_470' 'Restaurant_443' 'Restaurant_186' 'Restaurant_356'
#  'Restaurant_448' 'Restaurant_362' 'Restaurant_465' 'Restaurant_240'
#  'Restaurant_96' 'Restaurant_229' 'Restaurant_490' 'Restaurant_191'
#  'Restaurant_250' 'Restaurant_31' 'Restaurant_372' 'Restaurant_114'
#  'Restaurant_140' 'Restaurant_22' 'Restaurant_35' 'Restaurant_225'
#  'Restaurant_268' 'Restaurant_172' 'Restaurant_480' 'Restaurant_363'
#  'Restaurant_148' 'Restaurant_403' 'Restaurant_461' 'Restaurant_217'
#  'Restaurant_170' 'Restaurant_102' 'Restaurant_32' 'Restaurant_195'
#  'Restaurant_150' 'Restaurant_83' 'Restaurant_414' 'Restaurant_202'
#  'Restaurant_163' 'Restaurant_236' 'Restaurant_146' 'Restaurant_457'
#  'Restaurant_483' 'Restaurant_123' 'Restaurant_249' 'Restaurant_111'
#  'Restaurant_55' 'Restaurant_360' 'Restaurant_116' 'Restaurant_218'
#  'Restaurant_122' 'Restaurant_97' 'Restaurant_214' 'Restaurant_189'
#  'Restaurant_418' 'Restaurant_420' 'Restaurant_329' 'Restaurant_435'
#  'Restaurant_72' 'Restaurant_196' 'Restaurant_174' 'Restaurant_57'
#  'Restaurant_322' 'Restaurant_203' 'Restaurant_307' 'Restaurant_328'
#  'Restaurant_318' 'Restaurant_320' 'Restaurant_194' 'Restaurant_100'
#  'Restaurant_393' 'Restaurant_62' 'Restaurant_67' 'Restaurant_158'
#  'Restaurant_340' 'Restaurant_422' 'Restaurant_207' 'Restaurant_324'
#  'Restaurant_266' 'Restaurant_499' 'Restaurant_39' 'Restaurant_121'
#  'Restaurant_173' 'Restaurant_408' 'Restaurant_281' 'Restaurant_430'
#  'Restaurant_36' 'Restaurant_459' 'Restaurant_157' 'Restaurant_177'
#  'Restaurant_59' 'Restaurant_286' 'Restaurant_168' 'Restaurant_69'
#  'Restaurant_110' 'Restaurant_160' 'Restaurant_298' 'Restaurant_371'
#  'Restaurant_444' 'Restaurant_469' 'Restaurant_439' 'Restaurant_8'
#  'Restaurant_458' 'Restaurant_238' 'Restaurant_104' 'Restaurant_99'
#  'Restaurant_228' 'Restaurant_60' 'Restaurant_456' 'Restaurant_421'
#  'Restaurant_312' 'Restaurant_326' 'Restaurant_263' 'Restaurant_65'
#  'Restaurant_279' 'Restaurant_382' 'Restaurant_396' 'Restaurant_367'
#  'Restaurant_19' 'Restaurant_251' 'Restaurant_98' 'Restaurant_18'
#  'Restaurant_10' 'Restaurant_325' 'Restaurant_79' 'Restaurant_12'
#  'Restaurant_446' 'Restaurant_230' 'Restaurant_476' 'Restaurant_431'
#  'Restaurant_495' 'Restaurant_291' 'Restaurant_400' 'Restaurant_46'
#  'Restaurant_433' 'Restaurant_70' 'Restaurant_264' 'Restaurant_452'
#  'Restaurant_409' 'Restaurant_319' 'Restaurant_16' 'Restaurant_162'
#  'Restaurant_159' 'Restaurant_108' 'Restaurant_351' 'Restaurant_126'
#  'Restaurant_1' 'Restaurant_115' 'Restaurant_464' 'Restaurant_181'
#  'Restaurant_361' 'Restaurant_265' 'Restaurant_66' 'Restaurant_254'
#  'Restaurant_354' 'Restaurant_52' 'Restaurant_167' 'Restaurant_283'
#  'Restaurant_54' 'Restaurant_176' 'Restaurant_256' 'Restaurant_53'
#  'Restaurant_124' 'Restaurant_308' 'Restaurant_296' 'Restaurant_137'
#  'Restaurant_3' 'Restaurant_285' 'Restaurant_462' 'Restaurant_105'
#  'Restaurant_227' 'Restaurant_323' 'Restaurant_179' 'Restaurant_92'
#  'Restaurant_432' 'Restaurant_436' 'Restaurant_134' 'Restaurant_411'
#  'Restaurant_200' 'Restaurant_309' 'Restaurant_190' 'Restaurant_317'
#  'Restaurant_300' 'Restaurant_410' 'Restaurant_257' 'Restaurant_156'
#  'Restaurant_460' 'Restaurant_152' 'Restaurant_208' 'Restaurant_369'
#  'Restaurant_424' 'Restaurant_377' 'Restaurant_120' 'Restaurant_353'
#  'Restaurant_339' 'Restaurant_493' 'Restaurant_113' 'Restaurant_398'
#  'Restaurant_478' 'Restaurant_14' 'Restaurant_304' 'Restaurant_78'
#  'Restaurant_26' 'Restaurant_412' 'Restaurant_23' 'Restaurant_345'
#  'Restaurant_184' 'Restaurant_415' 'Restaurant_20' 'Restaurant_81'
#  'Restaurant_299' 'Restaurant_84' 'Restaurant_119' 'Restaurant_275'
#  'Restaurant_45' 'Restaurant_288' 'Restaurant_338' 'Restaurant_498'
#  'Restaurant_212' 'Restaurant_343' 'Restaurant_301' 'Restaurant_381'
#  'Restaurant_24' 'Restaurant_28' 'Restaurant_316' 'Restaurant_426'
#  'Restaurant_142' 'Restaurant_287' 'Restaurant_64' 'Restaurant_451'
#  'Restaurant_205' 'Restaurant_355' 'Restaurant_348' 'Restaurant_482'
#  'Restaurant_260' 'Restaurant_223' 'Restaurant_171' 'Restaurant_380'
#  'Restaurant_349' 'Restaurant_154' 'Restaurant_392' 'Restaurant_235'
#  'Restaurant_187' 'Restaurant_472' 'Restaurant_290' 'Restaurant_434'
#  'Restaurant_277' 'Restaurant_58' 'Restaurant_136' 'Restaurant_199'
#  'Restaurant_106' 'Restaurant_402' 'Restaurant_4' 'Restaurant_201'
#  'Restaurant_282' 'Restaurant_366' 'Restaurant_306' 'Restaurant_255'
#  'Restaurant_252' 'Restaurant_473' 'Restaurant_34' 'Restaurant_405'
#  'Restaurant_21' 'Restaurant_399' 'Restaurant_226' 'Restaurant_272'
#  'Restaurant_87' 'Restaurant_359' 'Restaurant_94' 'Restaurant_453'
#  'Restaurant_481' 'Restaurant_334' 'Restaurant_294' 'Restaurant_132'
#  'Restaurant_33' 'Restaurant_280' 'Restaurant_71' 'Restaurant_485'
#  'Restaurant_384' 'Restaurant_335' 'Restaurant_463' 'Restaurant_169'
#  'Restaurant_61' 'Restaurant_204' 'Restaurant_95' 'Restaurant_292'
#  'Restaurant_74' 'Restaurant_112' 'Restaurant_241' 'Restaurant_352'
#  'Restaurant_220' 'Restaurant_479' 'Restaurant_406' 'Restaurant_243'
#  'Restaurant_27' 'Restaurant_314' 'Restaurant_394' 'Restaurant_383'
#  'Restaurant_474' 'Restaurant_135' 'Restaurant_48' 'Restaurant_358'
#  'Restaurant_385' 'Restaurant_407' 'Restaurant_375' 'Restaurant_423'
#  'Restaurant_50' 'Restaurant_247' 'Restaurant_82' 'Restaurant_143'
#  'Restaurant_109' 'Restaurant_93' 'Restaurant_198' 'Restaurant_388'
#  'Restaurant_216' 'Restaurant_128' 'Restaurant_311' 'Restaurant_118'
#  'Restaurant_466' 'Restaurant_80' 'Restaurant_76' 'Restaurant_370'
#  'Restaurant_364' 'Restaurant_267' 'Restaurant_73' 'Restaurant_77'
#  'Restaurant_175' 'Restaurant_188' 'Restaurant_89' 'Restaurant_347'
#  'Restaurant_197' 'Restaurant_467' 'Restaurant_330' 'Restaurant_129'
#  'Restaurant_274' 'Restaurant_130' 'Restaurant_6' 'Restaurant_49'
#  'Restaurant_391' 'Restaurant_297' 'Restaurant_357' 'Restaurant_500'
#  'Restaurant_107' 'Restaurant_321' 'Restaurant_101' 'Restaurant_193'
#  'Restaurant_389' 'Restaurant_213' 'Restaurant_416' 'Restaurant_373'
#  'Restaurant_417' 'Restaurant_183' 'Restaurant_86' 'Restaurant_37'
#  'Restaurant_310' 'Restaurant_44' 'Restaurant_164' 'Restaurant_30'
#  'Restaurant_151' 'Restaurant_209' 'Restaurant_91' 'Restaurant_386'
#  'Restaurant_9' 'Restaurant_270' 'Restaurant_427' 'Restaurant_259'
#  'Restaurant_477' 'Restaurant_271' 'Restaurant_141' 'Restaurant_488'
#  'Restaurant_284' 'Restaurant_437' 'Restaurant_341' 'Restaurant_395'
#  'Restaurant_90' 'Restaurant_149' 'Restaurant_166' 'Restaurant_75'
#  'Restaurant_246' 'Restaurant_211' 'Restaurant_125' 'Restaurant_486'
#  'Restaurant_147' 'Restaurant_332' 'Restaurant_182' 'Restaurant_484'
#  'Restaurant_390' 'Restaurant_278' 'Restaurant_206' 'Restaurant_445'
#  'Restaurant_365' 'Restaurant_133' 'Restaurant_337' 'Restaurant_231'
#  'Restaurant_261' 'Restaurant_11' 'Restaurant_239' 'Restaurant_38'
#  'Restaurant_17' 'Restaurant_333' 'Restaurant_221' 'Restaurant_440'
#  'Restaurant_232' 'Restaurant_336' 'Restaurant_376' 'Restaurant_327'
#  'Restaurant_234' 'Restaurant_222' 'Restaurant_273' 'Restaurant_245'
#  'Restaurant_425' 'Restaurant_13' 'Restaurant_496' 'Restaurant_491'
#  'Restaurant_489' 'Restaurant_42' 'Restaurant_185' 'Restaurant_442'
#  'Restaurant_210' 'Restaurant_441' 'Restaurant_303' 'Restaurant_192'
#  'Restaurant_331' 'Restaurant_180' 'Restaurant_88' 'Restaurant_379'
#  'Restaurant_350' 'Restaurant_429' 'Restaurant_468' 'Restaurant_404'
#  'Restaurant_145' 'Restaurant_165' 'Restaurant_305' 'Restaurant_68'
#  'Restaurant_401' 'Restaurant_224' 'Restaurant_344' 'Restaurant_315'
#  'Restaurant_242' 'Restaurant_63' 'Restaurant_7' 'Restaurant_295']
#
# 📌 Column: Order_Status
# ['Delivered' 'Cancelled']
#
# 📌 Column: Cancellation_Reason
# ['Nan' 'Late Delivery' 'Customer Cancelled' 'Restaurant Issue']
#
# 📌 Column: Payment_Mode
# ['Upi' 'Cod' 'Wallet' 'Card']

# %%
#To see value counts

for col in cat_cols:
    print(f"\n📊 Value counts for {col}")
    print(df[col].value_counts())
# Out:
# 📊 Value counts for City
# City
# Hyderabad    22952
# Bangalore    11445
# Delhi        11370
# Chennai      11319
# Mumbai       11280
# Name: count, dtype: int64
#
# 📊 Value counts for Area
# Area
# South      22845
# Central    11454
# North      11394
# West       11368
# East       11305
# Name: count, dtype: int64
#
# 📊 Value counts for Cuisine_Type
# Cuisine_Type
# Indian     22951
# Chinese    11522
# Arabian    11379
# Mexican    11336
# Italian    11178
# Name: count, dtype: int64
#
# 📊 Value counts for Restaurant_Name
# Restaurant_Name
# Restaurant_338    173
# Restaurant_74     172
# Restaurant_453    169
# Restaurant_309    168
# Restaurant_422    167
#                  ...
# Restaurant_292    112
# Restaurant_398    112
# Restaurant_101    111
# Restaurant_268    109
# Restaurant_231     98
# Name: count, Length: 500, dtype: int64
#
# 📊 Value counts for Order_Status
# Order_Status
# Delivered    58029
# Cancelled    10337
# Name: count, dtype: int64
#
# 📊 Value counts for Cancellation_Reason
# Cancellation_Reason
# Nan                   62161
# Late Delivery          2116
# Customer Cancelled     2062
# Restaurant Issue       2027
# Name: count, dtype: int64
#
# 📊 Value counts for Payment_Mode
# Payment_Mode
# Card      27446
# Upi       13651
# Cod       13650
# Wallet    13619
# Name: count, dtype: int64

# %%
# ==============================
# LOGICAL CONSISTENCY CLEANING
# ==============================

# 1️⃣ Standardize Order_Status text
df['Order_Status'] = df['Order_Status'].astype(str).str.strip().str.title()

# 2️⃣ Clip ratings between 1 and 5
df['Restaurant_Rating'] = df['Restaurant_Rating'].clip(1, 5)
df['Delivery_Rating'] = df['Delivery_Rating'].clip(1, 5)

# 3️⃣ Remove ratings & delivery time for Cancelled orders
import numpy as np

df.loc[df['Order_Status'] == 'Cancelled',
       ['Delivery_Rating', 'Restaurant_Rating', 'Delivery_Time_Min']] = np.nan

# 4️⃣ Ensure Cancelled orders have Cancellation Reason
df.loc[(df['Order_Status'] == 'Cancelled') &
       (df['Cancellation_Reason'].isna()),
       'Cancellation_Reason'] = 'Not Specified'

# 5️⃣ Ensure Completed orders do NOT have Cancellation Reason
df.loc[df['Order_Status'] == 'Completed',
       'Cancellation_Reason'] = None

# 6️⃣ Fix negative discount values
df['Discount_Applied'] = df['Discount_Applied'].clip(lower=0)

# 7️⃣ Ensure Final_Amount calculation is correct
df['Final_Amount'] = df['Order_Value'] - df['Discount_Applied']

# 8️⃣ Remove negative profit
df['Profit_Margin'] = df['Profit_Margin'].clip(lower=0)

# 9️⃣ No profit for Cancelled orders
df.loc[df['Order_Status'] == 'Cancelled',
       'Profit_Margin'] = 0

# 🔟 Final Validation Summary
print("✅ Data Cleaning Completed")
print("\nRemaining Issues Check:")

print("Cancelled orders with ratings:",
      df[(df['Order_Status']=='Cancelled') &
         (df['Delivery_Rating'].notna())].shape[0])

print("Completed orders with cancellation reason:",
      df[(df['Order_Status']=='Completed') &
         (df['Cancellation_Reason'].notna())].shape[0])

print("Negative Profit rows:",
      df[df['Profit_Margin'] < 0].shape[0])
# Out:
# ✅ Data Cleaning Completed
#
# Remaining Issues Check:
# Cancelled orders with ratings: 0
# Completed orders with cancellation reason: 0
# Negative Profit rows: 0

# %%
df.fillna({
    'Delivery_Time_Min': df['Delivery_Time_Min'].mean(),
    'Delivery_Rating': df['Delivery_Rating'].median(),
    'Restaurant_Rating': df['Restaurant_Rating'].median()
}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Order_ID                    0
# Customer_ID                 0
# Customer_Age                0
# Customer_Gender             0
# City                        0
# Area                        0
# Restaurant_ID               0
# Restaurant_Name             0
# Cuisine_Type                0
# Order_Date                  0
# Order_Time                  0
# Delivery_Time_Min           0
# Distance_km                 0
# Order_Value                 0
# Discount_Applied            0
# Final_Amount                0
# Payment_Mode                0
# Order_Status                0
# Cancellation_Reason         0
# Delivery_Partner_ID         0
# Delivery_Rating             0
# Restaurant_Rating           0
# Order_Day                   0
# Peak_Hour                   0
# Profit_Margin               0
# Delivery_Rating_Missing     0
# Day_Type                    0
# Order_Hour                  0
# Peak_Indicator              0
# Profit_Margin_Percentage    0
# dtype: int64

# %%
df.shape
# Out:
# (68366, 30)

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# # Distribution of order values and delivery time

# %%
# 📊 Histogram -order value

import matplotlib.pyplot as plt

plt.figure()
plt.hist(df['Order_Value'].dropna(), bins=30)
plt.title("Distribution of Order Value")
plt.xlabel("Order Value")
plt.ylabel("Frequency")
plt.show()

#Step 1:Calculating basic statistics
df['Order_Value'].describe()
print(df['Order_Value'].describe())

#Step 2: Calculating Skewness
df['Order_Value'].skew()

#Step 3: Calculating Kurtosis
df['Order_Value'].kurt()
# Out:
# count    68366.000000
# mean      1787.205775
# std       1333.985753
# min        150.000000
# 25%        943.000000
# 50%       1197.000000
# 75%       2735.000000
# max       5000.000000
# Name: Order_Value, dtype: float64
# np.float64(-0.3591396635173161)

# %%
#📈 Boxplot – Detect Outliers for order value

plt.figure()
plt.boxplot(df['Order_Value'].dropna())
plt.title("Boxplot of Order Value")
plt.ylabel("Order Value")
plt.show()

# %%
#Distribution of Delivery Time
# 📊 Histogram – Delivery Time
plt.figure()
plt.hist(df['Delivery_Time_Min'].dropna(), bins=30)
plt.title("Distribution of Delivery Time")
plt.xlabel("Delivery Time (Minutes)")
plt.ylabel("Frequency")
plt.show()


#📈 Boxplot – Delivery Time

plt.figure()
plt.boxplot(df['Delivery_Time_Min'].dropna())
plt.title("Boxplot of Delivery Time")
plt.ylabel("Delivery Time (Minutes)")
plt.show()

print(df['Delivery_Time_Min'].describe())
df['Delivery_Time_Min'].skew()
# Out:
# count    58029.000000
# mean        -0.000268
# std          1.000825
# min         -1.452258
# 25%         -0.938181
# 50%          0.001712
# 75%          0.495822
# max          2.335674
# Name: Delivery_Time_Min, dtype: float64
# np.float64(0.5031225411388224)

# %%
#City-wise and cuisine-wise order analysis

#Step 1: create grouped data

import pandas as pd
city_cuisine = df.groupby(['City','Cuisine_Type']).size().reset_index(name='Orders')

print(city_cuisine.sort_values(by='Orders', ascending=False))
# Out:
#          City Cuisine_Type  Orders
# 17  Hyderabad       Indian    7715
# 7     Chennai       Indian    3852
# 15  Hyderabad      Arabian    3847
# 16  Hyderabad      Chinese    3832
# 2   Bangalore       Indian    3816
# 12      Delhi       Indian    3801
# 18  Hyderabad      Italian    3797
# 22     Mumbai       Indian    3767
# 19  Hyderabad      Mexican    3761
# 4   Bangalore      Mexican    1946
# 1   Bangalore      Chinese    1938
# 6     Chennai      Chinese    1933
# 14      Delhi      Mexican    1929
# 11      Delhi      Chinese    1914
# 21     Mumbai      Chinese    1905
# 10      Delhi      Arabian    1905
# 0   Bangalore      Arabian    1897
# 24     Mumbai      Mexican    1877
# 20     Mumbai      Arabian    1869
# 23     Mumbai      Italian    1862
# 5     Chennai      Arabian    1861
# 8     Chennai      Italian    1850
# 3   Bangalore      Italian    1848
# 9     Chennai      Mexican    1823
# 13      Delhi      Italian    1821

# %%
#Step 2: using pivot table for analysis for city vs cuisine wise

import matplotlib.pyplot as plt
pivot_table = pd.pivot_table(df,
                             values='Order_ID',
                             index='City',
                             columns='Cuisine_Type',
                             aggfunc='count')

pivot_table.plot(kind='bar')
plt.title("City-wise Cuisine Distribution")
plt.xlabel("City")
plt.ylabel("Total Orders")
plt.xticks(rotation=45)
plt.show()

# %%
# EDA analysis for Weekend vs weekday demand
# ==========================================
# FULL EDA: WEEKEND VS WEEKDAY DEMAND
# ==========================================

import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------
# 1️⃣ Prepare Data
# -------------------------------

df['Order_Date'] = pd.to_datetime(df['Order_Date'])
df['Order_Day'] = df['Order_Date'].dt.day_name()

df['Day_Type'] = df['Order_Day'].apply(
    lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday'
)

# -------------------------------
# 2️⃣ Order Volume Analysis
# -------------------------------

order_volume = df.groupby('Day_Type').size()

plt.figure()
plt.plot(order_volume.index, order_volume.values, marker='o')
plt.title("Order Volume: Weekend vs Weekday")
plt.xlabel("Day Type")
plt.ylabel("Total Orders")
plt.show()

# -------------------------------
# 3️⃣ Revenue Analysis
# -------------------------------

revenue = df.groupby('Day_Type')['Final_Amount'].sum()

plt.figure()
plt.plot(revenue.index, revenue.values, marker='o')
plt.title("Revenue Comparison")
plt.xlabel("Day Type")
plt.ylabel("Total Revenue")
plt.show()

# -------------------------------
# 4️⃣ Average Order Value
# -------------------------------

avg_order_value = df.groupby('Day_Type')['Order_Value'].mean()

plt.figure()
plt.plot(avg_order_value.index, avg_order_value.values, marker='o')
plt.title("Average Order Value")
plt.xlabel("Day Type")
plt.ylabel("Avg Order Value")
plt.show()

# -------------------------------
# 5️⃣ Average Delivery Time
# -------------------------------

avg_delivery = df.groupby('Day_Type')['Delivery_Time_Min'].mean()

plt.figure()
plt.plot(avg_delivery.index, avg_delivery.values, marker='o')
plt.title("Average Delivery Time")
plt.xlabel("Day Type")
plt.ylabel("Avg Delivery Time (Min)")
plt.show()

# -------------------------------
# 6️⃣ Cancellation Rate
# -------------------------------

cancel_rate = df.groupby('Day_Type')['Order_Status'] \
                .value_counts(normalize=True) \
                .unstack()

print("\nCancellation Rate:")
print(cancel_rate)

# -------------------------------
# 7️⃣ Profit Analysis
# -------------------------------

profit = df.groupby('Day_Type')['Profit_Margin'].sum()

plt.figure()
plt.plot(profit.index, profit.values, marker='o')
plt.title("Total Profit Comparison")
plt.xlabel("Day Type")
plt.ylabel("Total Profit")
plt.show()

# -------------------------------
# 8️⃣ Final Summary Table
# -------------------------------

summary = df.groupby('Day_Type').agg({
    'Order_ID': 'count',
    'Final_Amount': 'sum',
    'Order_Value': 'mean',
    'Delivery_Time_Min': 'mean',
    'Profit_Margin': 'sum'
}).rename(columns={
    'Order_ID': 'Total_Orders',
    'Final_Amount': 'Total_Revenue',
    'Order_Value': 'Avg_Order_Value',
    'Delivery_Time_Min': 'Avg_Delivery_Time',
    'Profit_Margin': 'Total_Profit'
})

print("\nFinal Summary Table:")
print(summary)
# Out:
# Cancellation Rate:
# Order_Status  Cancelled  Delivered
# Day_Type
# Weekday        0.151479   0.848521
# Weekend        0.150498   0.849502
# Final Summary Table:
#           Total_Orders  Total_Revenue  Avg_Order_Value  Avg_Delivery_Time  \
# Day_Type
# Weekday          48997     83863115.0      1789.766210           0.000153
# Weekend          19369     32967505.0      1780.728742          -0.001334
#
#           Total_Profit
# Day_Type
# Weekday        7433.31
# Weekend        2948.17

# %%
#Distance vs delivery delay relationship
# ==========================================
# DISTANCE vs DELIVERY TIME ANALYSIS
# ==========================================

import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Remove missing values
df_temp = df[['Distance_km', 'Delivery_Time_Min']].dropna()

# 2️⃣ Create distance bins (grouping)
df_temp['Distance_Group'] = pd.cut(
    df_temp['Distance_km'],
    bins=5
)

# 3️⃣ Calculate average delivery time per distance group
distance_delay = df_temp.groupby('Distance_Group',observed=False)['Delivery_Time_Min'].mean()

# 4️⃣ Line Plot
plt.figure()
plt.plot(distance_delay.index.astype(str),
         distance_delay.values,
         marker='o')

plt.title("Distance vs Average Delivery Time")
plt.xlabel("Distance Group (km)")
plt.ylabel("Average Delivery Time (Minutes)")
plt.xticks(rotation=45)
plt.show()

# 5️⃣ Print Summary
print("\nDistance vs Delivery Time Summary:")
print(distance_delay)
# Out:
# Distance vs Delivery Time Summary:
# Distance_Group
# (-1.275, -0.527]   -0.013214
# (-0.527, 0.218]     0.000515
# (0.218, 0.963]      0.005179
# (0.963, 1.707]      0.018502
# (1.707, 2.452]      0.008588
# Name: Delivery_Time_Min, dtype: float64

# %%
correlation = df_temp['Distance_km'].corr(df_temp['Delivery_Time_Min'])
print("Correlation:", correlation)
# Out:
# Correlation: 0.007441885448328939

# %%
#Cancellation reasons analysis
# ==========================================
# CANCELLATION REASONS EDA
# ==========================================

import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Filter only cancelled orders
cancel_df = df[df['Order_Status'].str.lower().str.contains('cancel')]

# 2️⃣ Count cancellation reasons
cancel_reason_counts = cancel_df['Cancellation_Reason'].value_counts()

# 3️⃣ Line Plot - Cancellation Reasons
plt.figure()
plt.plot(cancel_reason_counts.index,
         cancel_reason_counts.values,
         marker='o')

plt.title("Cancellation Reasons Distribution")
plt.xlabel("Cancellation Reason")
plt.ylabel("Number of Cancellations")
plt.xticks(rotation=45)
plt.show()

# 4️⃣ Percentage Distribution
cancel_percentage = cancel_df['Cancellation_Reason'].value_counts(normalize=True) * 100

print("\nCancellation Reason Percentage:")
print(cancel_percentage)

# 5️⃣ Cancellation Rate Overall
total_orders = df.shape[0]
total_cancelled = cancel_df.shape[0]

print("\nOverall Cancellation Rate:")
print((total_cancelled / total_orders) * 100, "%")
# Out:
# Cancellation Reason Percentage:
# Cancellation_Reason
# Nan                   39.972913
# Late Delivery         20.470156
# Customer Cancelled    19.947760
# Restaurant Issue      19.609171
# Name: proportion, dtype: float64
#
# Overall Cancellation Rate:
# 15.1200889330954 %

# %%
print(df['Order_Status'].unique())
# Out:
# ['Delivered' 'Cancelled']

# %%
####Correlation analysis among numeric features##########
# ==========================================
# CORRELATION ANALYSIS - NUMERIC FEATURES
# ==========================================

import pandas as pd
import matplotlib.pyplot as plt

# 1️⃣ Select numeric columns only
numeric_cols = df.select_dtypes(include=['int64', 'float64'])

# 2️⃣ Compute correlation matrix
correlation_matrix = numeric_cols.corr()

print("\nCorrelation Matrix:")
print(correlation_matrix)

# 3️⃣ Heatmap Visualization
plt.figure()
plt.imshow(correlation_matrix)
plt.colorbar()
plt.xticks(range(len(correlation_matrix.columns)),
           correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)),
           correlation_matrix.columns)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                          Customer_Age  Delivery_Time_Min  Distance_km  \
# Customer_Age                 1.000000          -0.013095    -0.009052
# Delivery_Time_Min           -0.013095           1.000000     0.007442
# Distance_km                 -0.009052           0.007442     1.000000
# Order_Value                 -0.003495           0.003641     0.000967
# Discount_Applied            -0.000346          -0.001081     0.002403
# Final_Amount                -0.003456           0.003714     0.000776
# Delivery_Rating             -0.002384          -0.002125    -0.001673
# Restaurant_Rating           -0.001240          -0.000266     0.004915
# Profit_Margin                0.000546          -0.001094     0.000991
# Delivery_Rating_Missing           NaN                NaN          NaN
#
#                          Order_Value  Discount_Applied  Final_Amount  \
# Customer_Age               -0.003495         -0.000346     -0.003456
# Delivery_Time_Min           0.003641         -0.001081      0.003714
# Distance_km                 0.000967          0.002403      0.000776
# Order_Value                 1.000000         -0.002983      0.996927
# Discount_Applied           -0.002983          1.000000     -0.081312
# Final_Amount                0.996927         -0.081312      1.000000
# Delivery_Rating             0.002578          0.003001      0.002335
# Restaurant_Rating          -0.004499          0.004053     -0.004803
# Profit_Margin               0.001998          0.005525      0.001558
# Delivery_Rating_Missing          NaN               NaN           NaN
#
#                          Delivery_Rating  Restaurant_Rating  Profit_Margin  \
# Customer_Age                   -0.002384          -0.001240       0.000546
# Delivery_Time_Min              -0.002125          -0.000266      -0.001094
# Distance_km                    -0.001673           0.004915       0.000991
# Order_Value                     0.002578          -0.004499       0.001998
# Discount_Applied                0.003001           0.004053       0.005525
# Final_Amount                    0.002335          -0.004803       0.001558
# Delivery_Rating                 1.000000           0.004069       0.001657
# Restaurant_Rating               0.004069           1.000000       0.000259
# Profit_Margin                   0.001657           0.000259       1.000000
# Delivery_Rating_Missing              NaN                NaN            NaN
#
#                          Delivery_Rating_Missing
# Customer_Age                                 NaN
# Delivery_Time_Min                            NaN
# Distance_km                                  NaN
# Order_Value                                  NaN
# Discount_Applied                             NaN
# Final_Amount                                 NaN
# Delivery_Rating                              NaN
# Restaurant_Rating                            NaN
# Profit_Margin                                NaN
# Delivery_Rating_Missing                      NaN

# %%
print(correlation_matrix.round(2))
# Out:
#                          Customer_Age  Delivery_Time_Min  Distance_km  \
# Customer_Age                     1.00              -0.01        -0.01
# Delivery_Time_Min               -0.01               1.00         0.01
# Distance_km                     -0.01               0.01         1.00
# Order_Value                     -0.00               0.00         0.00
# Discount_Applied                -0.00              -0.00         0.00
# Final_Amount                    -0.00               0.00         0.00
# Delivery_Rating                 -0.00              -0.00        -0.00
# Restaurant_Rating               -0.00              -0.00         0.00
# Profit_Margin                    0.00              -0.00         0.00
# Delivery_Rating_Missing           NaN                NaN          NaN
#
#                          Order_Value  Discount_Applied  Final_Amount  \
# Customer_Age                    -0.0             -0.00         -0.00
# Delivery_Time_Min                0.0             -0.00          0.00
# Distance_km                      0.0              0.00          0.00
# Order_Value                      1.0             -0.00          1.00
# Discount_Applied                -0.0              1.00         -0.08
# Final_Amount                     1.0             -0.08          1.00
# Delivery_Rating                  0.0              0.00          0.00
# Restaurant_Rating               -0.0              0.00         -0.00
# Profit_Margin                    0.0              0.01          0.00
# Delivery_Rating_Missing          NaN               NaN           NaN
#
#                          Delivery_Rating  Restaurant_Rating  Profit_Margin  \
# Customer_Age                        -0.0               -0.0           0.00
# Delivery_Time_Min                   -0.0               -0.0          -0.00
# Distance_km                         -0.0                0.0           0.00
# Order_Value                          0.0               -0.0           0.00
# Discount_Applied                     0.0                0.0           0.01
# Final_Amount                         0.0               -0.0           0.00
# Delivery_Rating                      1.0                0.0           0.00
# Restaurant_Rating                    0.0                1.0           0.00
# Profit_Margin                        0.0                0.0           1.00
# Delivery_Rating_Missing              NaN                NaN            NaN
#
#                          Delivery_Rating_Missing
# Customer_Age                                 NaN
# Delivery_Time_Min                            NaN
# Distance_km                                  NaN
# Order_Value                                  NaN
# Discount_Applied                             NaN
# Final_Amount                                 NaN
# Delivery_Rating                              NaN
# Restaurant_Rating                            NaN
# Profit_Margin                                NaN
# Delivery_Rating_Missing                      NaN

# %% [markdown]
# # **Feature Engineering**

# %%
#order day type weekday/weekend

# ==========================================
# DERIVED COLUMN: WEEKDAY / WEEKEND
# ==========================================

import pandas as pd

# 1️⃣ Convert Order_Date to datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# 2️⃣ Extract Day Name
df['Order_Day'] = df['Order_Date'].dt.day_name()

# 3️⃣ Create Day_Type column
df['Day_Type'] = df['Order_Day'].apply(
    lambda x: 'Weekend' if x in ['Saturday', 'Sunday'] else 'Weekday'
)

# 4️⃣ Check result
print(df[['Order_Date', 'Order_Day', 'Day_Type']].head())

#Box plot for demand comparsion
import matplotlib.pyplot as plt

demand = df['Day_Type'].value_counts()

plt.bar(demand.index, demand.values)
plt.title("Weekend vs Weekday Demand")
plt.xlabel("Day Type")
plt.ylabel("Number of Orders")
plt.show()


#to compare order value
import seaborn as sns

sns.boxplot(x='Day_Type', y='Order_Value', data=df)
plt.title("Order Value Distribution: Weekend vs Weekday")
plt.show()
# Out:
#   Order_Date Order_Day Day_Type
# 0 2024-10-20    Sunday  Weekend
# 1 2024-08-12    Monday  Weekday
# 2 2024-12-08    Sunday  Weekend
# 3 2024-10-08   Tuesday  Weekday
# 4 2024-02-04    Sunday  Weekend

# %%
df["Order_Day"].unique()
# Out:
# array(['Weekend', 'Weekday'], dtype=object)

# %%
#======Peak hour indicator========


# Step 1:convert Order_Time todateti

import pandas as pd

# Convert to datetime (already converted )
df['Order_Time'] = pd.to_datetime(df['Order_Time'], errors='coerce')

# Extract hour
df['Order_Hour'] = df['Order_Time'].dt.hour


# Step 2: Create peak hour indicator
df['Peak_Indicator'] = df['Order_Hour'].apply(lambda x: 'Lunch Peak' if 12 <= x <= 15 else ('Dinner Peak' if 19 <= x <= 22
          else 'Non-Peak')
)

#Step 3: Checking results
print(df[['Order_Time', 'Order_Hour', 'Peak_Indicator']].head())

# Step 4:📊 EDA: Orders During Peak vs Non-Peak

import matplotlib.pyplot as plt

peak_counts = df['Peak_Indicator'].value_counts()

# Generate dynamic colors
colors = plt.cm.Set3(range(len(peak_counts)))

plt.pie(peak_counts.values,
        labels=peak_counts.index,
        autopct='%1.1f%%',
        colors=colors,
        shadow=True,
        startangle=90)

plt.title("Peak vs Non-Peak Order Distribution")
plt.axis('equal')
plt.show()
# Out:
#   Order_Time  Order_Hour Peak_Indicator
# 0 2026-03-04           0       Non-Peak
# 1 2026-03-04           0       Non-Peak
# 2 2026-03-04           0       Non-Peak
# 3 2026-03-04           0       Non-Peak
# 4 2026-03-04           0       Non-Peak

# %%
print(df['Order_Time'].head())
print(df['Order_Time'].tail())
print(df['Order_Time'].dtype)
# Out:
# 0   2026-03-04
# 1   2026-03-04
# 2   2026-03-04
# 3   2026-03-04
# 4   2026-03-04
# Name: Order_Time, dtype: datetime64[ns]
# 99993   2026-03-04
# 99995   2026-03-04
# 99996   2026-03-04
# 99997   2026-03-04
# 99999   2026-03-04
# Name: Order_Time, dtype: datetime64[ns]
# datetime64[ns]

# %%
#==========================
#Profit margin percentage
#======================
#Step 1: Create Profit Margin Percentage Column

df['Profit_Margin_Percentage'] = (df['Profit_Margin'] / df['Order_Value']) * 100
print(df[['Profit_Margin_Percentage', 'Order_Value', 'Profit_Margin']].head())

#Step 2: Average Profit Margin by City
df.groupby('City')['Profit_Margin_Percentage'].mean()

#Step 3: By Cuisine
df.groupby('Cuisine_Type')['Profit_Margin_Percentage'].mean()

#Step 4:Distribution
df['Profit_Margin_Percentage'].hist()
plt.title("Distribution of Profit Margin Percentage")
plt.xlabel("Profit Margin Percentage")
plt.ylabel("Frequency")
plt.show()

#Step 4: correlation analysis
correlation = df['Profit_Margin_Percentage'].corr(df['Order_Value'])
print("Correlation:", correlation)

#Step 5: for correlation analysis
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True)
plt.show()
# Out:
#    Profit_Margin_Percentage  Order_Value  Profit_Margin
# 0                  0.010860       1197.0           0.13
# 1                  0.009858       4869.0           0.48
# 2                  0.010568        757.0           0.08
# 3                  0.000000       1197.0           0.00
# 4                  0.032258        372.0           0.12
# Correlation: -0.3403901760495245

# %%
#Delivery performance categories

#Step 1: Reload Original Data (To Get Raw Minutes)
import pandas as pd

df_original = pd.read_csv("/content/ONINE_FOOD_DELIVERY_ANALYSIS.csv")

df_original['Delivery_Time_Min'] = pd.to_numeric(
    df_original['Delivery_Time_Min'], errors='coerce'
)

#Step 2: Reload Original Data (To Get Raw Minutes)
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_scaled = df_original.copy()

#df_original -real minutes
#df_scaled --- standardized values

df_scaled['Delivery_Time_Min'] = scaler.fit_transform(
    df_scaled[['Delivery_Time_Min']]
)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))

# Original
plt.subplot(1,2,1)
plt.hist(df_original['Delivery_Time_Min'].dropna(), bins=30)
plt.title("Original Delivery Time (Minutes)")

# Scaled
plt.subplot(1,2,2)
plt.hist(df_scaled['Delivery_Time_Min'].dropna(), bins=30)
plt.title("Scaled Delivery Time")

plt.tight_layout()
plt.show()

# %%
# Customer age groups


#without creating column for temporary
import pandas as pd
import numpy as np

age_groups = pd.cut(
    df['Customer_Age'],
    bins=[18, 25, 35, 50, np.inf],
    labels=['Young Adults', 'Adults', 'Middle Age', 'Senior'],
    include_lowest=True
)

print(age_groups.value_counts())

#Data visualization
import matplotlib.pyplot as plt

counts = age_groups.value_counts().sort_index()

plt.figure()
plt.bar(counts.index.astype(str), counts.values)
plt.title("Customer Age Group Distribution")
plt.xlabel("Age Group")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)
plt.show()
# Out:
# Customer_Age
# Middle Age      46308
# Adults           7913
# Senior           7807
# Young Adults     6338
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Order_ID                    0
# Customer_ID                 0
# Customer_Age                0
# Customer_Gender             0
# City                        0
# Area                        0
# Restaurant_ID               0
# Restaurant_Name             0
# Cuisine_Type                0
# Order_Date                  0
# Order_Time                  0
# Delivery_Time_Min           0
# Distance_km                 0
# Order_Value                 0
# Discount_Applied            0
# Final_Amount                0
# Payment_Mode                0
# Order_Status                0
# Cancellation_Reason         0
# Delivery_Partner_ID         0
# Delivery_Rating             0
# Restaurant_Rating           0
# Order_Day                   0
# Peak_Hour                   0
# Profit_Margin               0
# Delivery_Rating_Missing     0
# Day_Type                    0
# Order_Hour                  0
# Peak_Indicator              0
# Profit_Margin_Percentage    0
# dtype: int64

# %%
df.to_csv("/content/cleaned_online_food_delivery_dataset.csv", index=False)

# %% [markdown]
# # 15 Query

# %% [markdown]
#  1.Identify top-spending customers

# %%
#----------------Queries---------
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Loaded cleaned dataset

df.to_csv("/content/cleaned_online_food_delivery_dataset.csv", index=False)
df.head()

# top-spending customers
top_customers = df.groupby("Customer_ID")["Final_Amount"].sum().reset_index()

top_customers = top_customers.sort_values(by="Final_Amount", ascending=False).head(10)

top_customers

#Data Visualization
plt.figure(figsize=(10,6))
sns.barplot(data=top_customers, x="Customer_ID", y="Final_Amount")

plt.title("Top 10 Customers by Total Spending")
plt.xlabel("Customer ID")
plt.ylabel("Total Spending")
plt.xticks(rotation=45)

plt.show()

# %%
#insights
#The visualization highlights the top 10 customers who contribute the highest revenue to the food delivery platform.
#A small group of customers contributes a significant portion of overall revenue.
#The top spenders can be classified as premium or VIP customers for targeted engagement.
#Upselling Opportunities:These customers may respond well to combo offers, premium menu items, or add-ons.
#Analyzing their order patterns can reveal preferred cuisines, peak order times, and payment methods.
#Identifying these high-value customers helps businesses implement targeted marketing strategies and loyalty programs to increase retention.

# %% [markdown]
# ## 2.Analyze age group vs order value

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# create age groups
df["Age_Group"] = pd.cut(
    df["Customer_Age"],
    bins=[18,25,35,45,55,65],
    labels=["18-25","26-35","36-45","46-55","56-65"]
)

df.head()

#calculating average order value
age_order_value = df.groupby("Age_Group",observed=False)["Order_Value"].mean().reset_index()
age_order_value


#Data visualization
plt.figure(figsize=(8,5))

sns.lineplot(data=age_order_value, x="Age_Group", y="Order_Value", marker="o")

plt.title("Average Order Value by Age Group")

plt.show()
age_order_value
# Out:
#   Age_Group  Order_Value
# 0     18-25  2064.253365
# 1     26-35  2103.277735
# 2     36-45  2053.710091
# 3     46-55  2106.031614
# 4     56-65  2025.604320

# %%
#Insights
1.Customers aged 26–35 show higher average order values, indicating stronger purchasing power.
2.The 18–25 age group tends to place smaller orders, possibly due to lower income or student population.
3.A few customers place significantly higher-value orders, which appear as outliers in the distribution.
4.Marketing Strategy Insight:Platforms can offer discounts for younger users and premium meal offers for higher-spending age groups.

# %% [markdown]
# # 3.Weekend vs weekday order patterns

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Create Weekday / Weekend column

df['Day_Type'] = df['Day_Name'].apply(lambda x: 'Weekend' if x in ['Saturday','Sunday'] else 'Weekday')
print(df[['Order_Date','Day_Name','Day_Type']].head())

order_counts = df.groupby('Day_Type')['Order_ID'].count().reset_index()

orders_by_day = df.groupby('Day_Name')['Order_ID'].count().reindex([
    'Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'
])

#Data Visualization
orders_by_day.plot(kind='bar')
plt.title('Orders by Day of Week')
plt.xlabel('Day')
plt.ylabel('Number of Orders')
plt.show()

df["Order_Day"].value_counts()
# Out:
#   Order_Date Day_Name Day_Type
# 0 2024-10-20   Sunday  Weekend
# 1 2024-08-12   Monday  Weekday
# 2 2024-12-08   Sunday  Weekend
# 3 2024-10-08  Tuesday  Weekday
# 4 2024-02-04   Sunday  Weekend
# Order_Day
# Weekday    71370
# Weekend    28630
# Name: count, dtype: int64

# %%
import pandas as pd

# Convert order date to datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# Extract day name
df['Day_Name'] = df['Order_Date'].dt.day_name()
# Out:
#   Order_Date Day_Name Day_Type
# 0 2024-10-20   Sunday  Weekend
# 1 2024-08-12   Monday  Weekday
# 2 2024-12-08   Sunday  Weekend
# 3 2024-10-08  Tuesday  Weekday
# 4 2024-02-04   Sunday  Weekend
#   Day_Type  Order_ID
# 0  Weekday     71632
# 1  Weekend     28368

# %%
#Insights
1.Increase delivery partners during weekend peak hours.
2.Offer special weekend promotions and combo deals.
3.Schedule additional restaurant staff on weekends.
4.Improve delivery route optimization to reduce delays.
5.Use targeted marketing campaigns to boost weekend orders.
6.Maintain sufficient inventory for high weekend demand.

# %% [markdown]
# # 4.Monthly revenue trends

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Monthly revenue
monthly_revenue = df.groupby('Month')['Final_Amount'].sum()

# Plot
monthly_revenue.plot(kind='line', marker='o')

plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.show()

# %%
#Insights
1.Monthly revenue fluctuates due to seasonal demand and promotions.
2.Peak months show higher customer activity and order volume.
3.Revenue growth suggests increasing platform adoption.
4.Increase marketing efforts in peak months.
5.Plan staffing and inventory based on demand trends.

# %% [markdown]
# ## 5.Impact of discounts on profit

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Data Visualization
avg_profit = df.groupby('Discount_Applied')['Profit_Margin'].mean().reset_index()

plt.plot(avg_profit['Discount_Applied'], avg_profit['Profit_Margin'], marker='o')

plt.title('Discount vs Profit Margin Trend')
plt.xlabel('Discount Applied')
plt.ylabel('Average Profit Margin')
plt.show()

# %%
#Insights
1.Higher discounts result in higher profit margins.
2.Moderate Discounts Can Maintain Profitability
3.High Discounts May Lead to Negative Profit
4.Set Minimum Order Value for Discounts
5.Analyze Customer Response to Discounts

# %% [markdown]
# # 6.High-revenue cities and cuisines

# %%
#Data visualization

#Stacked Bar Chart
pivot = df.pivot_table(values='Final_Amount',
                       index='City',
                       columns='Cuisine_Type',
                       aggfunc='sum')

pivot.plot(kind='bar', stacked=True, figsize=(12,6))

plt.title('City-wise Revenue by Cuisine')
plt.xlabel('City')
plt.ylabel('Revenue')
plt.show()

# %%
#Insights
1.Certain Cities Generate Higher Revenue
2.Popular Cuisines Drive Major Revenue
3.High Order Value in Urban Areas
4.Focus Marketing on High-Revenue Cities
5.Support Restaurants in Low-Revenue Areas

# %% [markdown]
# # 7.Average delivery time by city

# %%
#Data Visualization

import seaborn as sns
import matplotlib.pyplot as plt

avg_delivery = df.groupby('City')['Delivery_Time_Min'].mean().reset_index()

plt.figure(figsize=(8,5))

sns.scatterplot(data=avg_delivery,
                x='City',
                y='Delivery_Time_Min',
                s=100)

plt.title('Average Delivery Time by City')
plt.xticks(rotation=45)

plt.show()

# %%
#Insights
1.Delivery Time Varies Across Cities
2.Distance Influences Delivery Time
3.Efficient Cities Show Faster Deliveries
4.Establish More Restaurant Hubs
5.Implement Smart Order Allocation

# %% [markdown]
# # 8.Distance vs delivery delay analysis

# %%
#Hexbin Plot (Better for Large Data)

plt.figure(figsize=(8,5))

plt.hexbin(df['Distance_km'], df['Delivery_Time_Min'], gridsize=30)

plt.xlabel('Distance (km)')
plt.ylabel('Delivery Time (Minutes)')
plt.title('Distance vs Delivery Time Density')
plt.show()

# %%
#Insights
1.Delivery time increases with longer delivery distances
2.Short-distance orders are delivered faster
3.Traffic and route efficiency also affect delivery time
4.Optimize delivery routes to reduce delays
5.Assign nearest delivery partners

# %% [markdown]
# 9.Delivery rating vs delivery time

# %%
plt.figure(figsize=(8,5))

sns.regplot(x='Delivery_Time_Min', y='Delivery_Rating', data=df)

plt.title('Delivery Time vs Delivery Rating Trend')
plt.xlabel('Delivery Time (Minutes)')
plt.ylabel('Delivery Rating')
plt.show()

# %%
#Insights
1.Other Factors Also Influence Ratings like Food Quality, Packaging, and Service
2.Delivery ratings are not only affected by time but also by delivery partner behavior.
3.Delivery Ratings Are Distributed Across All Delivery Times
4.Provide accurate delivery time estimates and real-time tracking to manage customer expectations
5.Monitor Delivery Performance

# %% [markdown]
# # 10.Top-rated restaurants

# %%
# Calculate average ratings for restaurants
cluster_data = df.groupby('Restaurant_Name')[['Restaurant_Rating','Delivery_Rating']].mean().head(10)

# Plot clustered bar chart
cluster_data.plot(kind='bar', figsize=(10,6))

plt.title('Restaurant Rating vs Delivery Rating')
plt.xlabel('Restaurant Name')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.legend(['Restaurant Rating','Delivery Rating'])

# %%
#Insights
1.Restaurant_103 and Restaurant_105 Have Strong Overall Performance
2.Delivery Experience Influences Overall Customer Satisfaction
3.Maintain High Food Quality
4.Balance Food and Delivery Performance

# %% [markdown]
# 11.Cancellation rate by restaurant

# %%
import pandas as pd
import matplotlib.pyplot as plt

cancel_data = pd.crosstab(df['Restaurant_Name'], df['Order_Status'])

cancel_data.head(10).plot(kind='bar', stacked=True, figsize=(10,6))

plt.title('Orders vs Cancelled Orders by Restaurant')
plt.xlabel('Restaurant Name')
plt.ylabel('Number of Orders')
plt.xticks(rotation=45)

plt.show()

# %%
#Insights
1.Restaurant_103 Has the Highest Order Volume and also has the Highest Cancellations
2.Some Restaurants Have Moderate Cancellation Levels
3.Improve Order Handling During Peak Demand
4.Replicate Best Practices

# %% [markdown]
# # 12.Cuisine-wise performance

# %%
#Data Visualization
import seaborn as sns

pivot = df.pivot_table(values='Final_Amount',
                       index='Cuisine_Type',
                       columns='City',
                       aggfunc='sum')

sns.heatmap(pivot, cmap='YlOrRd')

plt.title('Cuisine Revenue by City')
plt.show()

# %%
#Insights
1.Indian Cuisine Generates the Highest Revenue
2.Different cities show different cuisine preferences, indicating regional taste differences among customers
3.Bangalore is the Highest Revenue City
4.Use promotions or discounts to boost demand for Italian cuisine.
5.Ensure sufficient restaurant availability for high-demand cuisines in each city.

# %% [markdown]
# 13.Peak hour demand analysis

# %%
#Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='Peak_Hour', y='Final_Amount', data=df, hue='Order_Status', palette='Set2')

plt.title('Revenue During Peak Hours')
plt.show()

# %% [markdown]
# 14.Payment mode prefrences

# %%
#Data visualization

# Count orders by payment mode
payment_counts = df['Payment_Mode'].value_counts()

plt.figure(figsize=(6,6))

plt.pie(payment_counts.values, labels=payment_counts.index,
        autopct='%1.1f%%', wedgeprops=dict(width=0.4))

plt.title('Payment Mode Preferences')

plt.show()

# %%
#Insights
1.Digital Payments Slightly Dominate
2.Flexible Payment Options Improve Customer Experience
3.COD still accounts for a significant portion of orders, meaning many customers prefer paying after receiving their order.
4.Use Payment Data for Promotions
5.Ensure secure and fast payment processing to increase trust in digital payments.

# %% [markdown]
# 15.Cancellation reason analysis

# %%
#Data Visualization
import matplotlib.pyplot as plt

# Filter cancelled orders
cancel_reasons = df[df['Order_Status'] == 'Cancelled']['Cancellation_Reason'].value_counts()

plt.figure(figsize=(10,6))

plt.bar(cancel_reasons.index, cancel_reasons.values, color='orange')

plt.title('Cancellation Reason Analysis')
plt.xlabel('Cancellation Reason')
plt.ylabel('Number of Cancellations')
plt.xticks(rotation=45)

plt.show()

# %%
#insights
1.Some Reasons Occur More Frequently
2.Efficient restaurant operations and faster delivery can significantly reduce cancellations
3.Improve Order Preparation Time
4.Ensure menu items are available to avoid restaurant cancellations.
5.Keeping customers informed about order status and delivery time can reduce cancellation rates.

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Customer_Age', 'Customer_Gender', 'City',
#        'Area', 'Restaurant_ID', 'Restaurant_Name', 'Cuisine_Type',
#        'Order_Date', 'Order_Time', 'Delivery_Time_Min', 'Distance_km',
#        'Order_Value', 'Discount_Applied', 'Final_Amount', 'Payment_Mode',
#        'Order_Status', 'Cancellation_Reason', 'Delivery_Partner_ID',
#        'Delivery_Rating', 'Restaurant_Rating', 'Order_Day', 'Peak_Hour',
#        'Profit_Margin'],
#       dtype='object')
